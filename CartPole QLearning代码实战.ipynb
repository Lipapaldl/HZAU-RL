# %%
# !pip install gym
# !pip install --upgrade gym[robotics]#完整安装
# Out:
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\xiandan\miniconda3\envs\d2l\lib\site-packages)
# ERROR: Invalid requirement: 'gym[robotics]#完整安装'
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\xiandan\miniconda3\envs\d2l\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\xiandan\miniconda3\envs\d2l\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\xiandan\miniconda3\envs\d2l\lib\site-packages)

# %% [markdown]
# # 查看 gym所有可用环境

# %%
import gym
from gym import envs

env_list = envs.registry.keys()
env_ids = [env_item for env_item in env_list]
print('There are {0} envs in gym'.format(len(env_ids)))
env_ids
# Out:
# There are 44 envs in gym
# ['CartPole-v0',
#  'CartPole-v1',
#  'MountainCar-v0',
#  'MountainCarContinuous-v0',
#  'Pendulum-v1',
#  'Acrobot-v1',
#  'LunarLander-v2',
#  'LunarLanderContinuous-v2',
#  'BipedalWalker-v3',
#  'BipedalWalkerHardcore-v3',
#  'CarRacing-v2',
#  'Blackjack-v1',
#  'FrozenLake-v1',
#  'FrozenLake8x8-v1',
#  'CliffWalking-v0',
#  'Taxi-v3',
#  'Reacher-v2',
#  'Reacher-v4',
#  'Pusher-v2',
#  'Pusher-v4',
#  'InvertedPendulum-v2',
#  'InvertedPendulum-v4',
#  'InvertedDoublePendulum-v2',
#  'InvertedDoublePendulum-v4',
#  'HalfCheetah-v2',
#  'HalfCheetah-v3',
#  'HalfCheetah-v4',
#  'Hopper-v2',
#  'Hopper-v3',
#  'Hopper-v4',
#  'Swimmer-v2',
#  'Swimmer-v3',
#  'Swimmer-v4',
#  'Walker2d-v2',
#  'Walker2d-v3',
#  'Walker2d-v4',
#  'Ant-v2',
#  'Ant-v3',
#  'Ant-v4',
#  'Humanoid-v2',
#  'Humanoid-v3',
#  'Humanoid-v4',
#  'HumanoidStandup-v2',
#  'HumanoidStandup-v4']

# %% [markdown]
# # make( )生成对象

# %%
'''
env = gym.make(id)
	说明：生成环境
	参数：Id(str类型)  环境ID
	返回值：env(Env类型)  环境
	
	环境ID是OpenAI Gym提供的环境的ID，可以通过上一节所述方式进行查看有哪些可用的环境
	例如，如果是“CartPole”环境，则ID可以用“CartPole-v1”。返回“Env”对象作为返回值
'''

# %%
env = gym.make('CartPole-v1')
print('观测空间 = {}'.format(env.observation_space))
print('动作空间 = {}'.format(env.action_space))
print('动作数 = {}'.format(env.action_space.n))
print('初始状态 = {}'.format(env.state))
# Out:
# 观测空间 = Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)
# 动作空间 = Discrete(2)
# 动作数 = 2
# 初始状态 = None

# %% [markdown]
# # reset()函数
#
# reset()为环境复位初始化函数。将环境的状态恢复到初始状态。
#
# 在一次任务的开始时必须调用reset()，哪怕是make()生成对象后的第一次任务。这是因为，make()生成对象后并没有顺便做一下初始化

# %%
'''
state = env.reset()
	说明：重置环境，回到初始状态
	返回值：state（object类型） 环境的最初状态。类型由属性“observation_space”决定
'''

# %%
init_state = env.reset()
print('初始状态 = {}'.format(init_state))
print('初始状态 = {}'.format(env.state))
# Out:
# 初始状态 = (array([ 0.01617031, -0.00685281, -0.04474193,  0.03938083], dtype=float32), {})
# 初始状态 = [ 0.01617031 -0.00685281 -0.04474193  0.03938083]

# %% [markdown]
# # env.state¶
# 查看环境当前状态

# %% [markdown]
# # env.step()：单步执行

# %% [markdown]
# 当然这里说的单步不是指软件程序调试中所指的运行一行代码之类的，而是指智能体与环境之间的一次交互，即智能体在当前状态s下执行一次动作a，环境相应地更新至状态s'，并向智能体反馈及时奖励r。

# %%
'''
Observation, reward, terminated, truncated, info = env.step(action)
	说明：环境执行一步动作
	参数：action（object 类型） 动作
	返回值：results（tuple 类型） (下一状态，报酬，episode 是否完成，日志信息)
	
	将“动作”传递给环境，返回值返回“下一个状态”（object）、“报酬”（float）、“ episode 是否完成”（bool）、“日志信息”（dict）
	传递给环境的“动作”类型，由属性“action_space”决定
'''

# %%
for k in range(5):
    action = env.action_space.sample()
    state, reward, done, truncated, info = env.step(action)
    print('动作 = {0}: 当前状态 = {1}, 奖励 = {2}, 结束标志 = {3}, 日志信息 = {4}'.format(action, state, reward, done, info))
# Out:
# 动作 = 1: 当前状态 = [ 0.01603325  0.18888123 -0.04395431 -0.26707613], 奖励 = 1.0, 结束标志 = False, 日志信息 = {}
# 动作 = 1: 当前状态 = [ 0.01981088  0.38460204 -0.04929584 -0.5732922 ], 奖励 = 1.0, 结束标志 = False, 日志信息 = {}
# 动作 = 1: 当前状态 = [ 0.02750292  0.58037925 -0.06076168 -0.8810884 ], 奖励 = 1.0, 结束标志 = False, 日志信息 = {}
# 动作 = 0: 当前状态 = [ 0.0391105   0.38613296 -0.07838345 -0.6081096 ], 奖励 = 1.0, 结束标志 = False, 日志信息 = {}
# 动作 = 0: 当前状态 = [ 0.04683316  0.1921893  -0.09054564 -0.3411085 ], 奖励 = 1.0, 结束标志 = False, 日志信息 = {}

# %% [markdown]
# # env.render()：环境显示

# %% [markdown]
# 以图形化的方式显示环境当前状态，在智能体与环境的持续交互过程中，该图形化显示也是相应地持续更新的。
#
#         env.render()所生成的图形窗口是以另外的独立的窗口出现。

# %% [markdown]
# env.render(mode='human')
#
# 	说明：渲染环境画面
#
# 	参数：mode（str类型） 渲染模式
#
# 	返回值：对应渲染模式的返回值
#
#
# 渲染模式参数	说明
#
# human	在人类显示器或终端上渲染
#
# rgb_array	返回像素图像的RGB阵列作为返回值
#
# ansi	将文本作为返回值返回

# %% [markdown]
# # env.close()：关闭环境
#         关闭环境。

# %% [markdown]
# # env.sample_space.sample(): 对动作空间进行随机采样
#
# 动作的选择应该基于策略进行。
#
# 但是，完全随机的选择动作也是一种策略，或者可以说是一种基线(baseline)策略。
#
# 任何一种能够体现有效的学习效果的策略都不应该比这种基线策略的效果差。
#
# 这就好比任何一个有效的预测（股票涨跌、球赛胜负啊随便什么的）算法不能比随机扔硬币决定要更差。
#
# 如果一种基于一种习得的策略来选取动作其最终得到的回报不比以上随机采样策略好的话，就说明这个习得的策略没有任何价值。

# %% [markdown]
# # env.seed()：指定随机种子

# %%
'''
env.seed(seed=None)
	说明：指定随机数种子
	参数：seed（int 类型） 随机种子
	返回值：seeds（list 类型） 在环境中使用的随机数种子列表
	用env.seed()指定环境的随机数种子。如果想要训练的再现性，或者想要根据不同的环境使用不同的随机数种子，就可以使用该方法
'''

# %% [markdown]
# # 完整demo

# %%
import gym
import time

#生成环境
env = gym.make('CartPole-v1',render_mode='human')

#环境初始化
state = env.reset()

#循环交互
while True:
    #渲染画面
#     env.render()
    
    #选择随机动作
    action = env.action_space.sample()
    
    #环境交互
    state,reward,terminated,truncated,info = env.step(action)
    
    #打印
    print("当前状态state = {};奖励reward = {}".format(state,reward))
    
    # 判断当前episode 是否完成
    if terminated:
        print("done")
        break
    time.sleep(1)
    
#环境结束
# env.close()
# Out:
# 当前状态state = [ 0.00594682 -0.21920168 -0.00754221  0.25963733];奖励reward = 1.0
# 当前状态state = [ 0.00156278 -0.41421515 -0.00234946  0.5499318 ];奖励reward = 1.0
# 当前状态state = [-0.00672152 -0.609304    0.00864917  0.8418736 ];奖励reward = 1.0
# 当前状态state = [-0.0189076  -0.4143012   0.02548665  0.5519231 ];奖励reward = 1.0
# 当前状态state = [-0.02719362 -0.60977167  0.03652511  0.85252583];奖励reward = 1.0
# 当前状态state = [-0.03938906 -0.805372    0.05357562  1.1564666 ];奖励reward = 1.0
# 当前状态state = [-0.0554965  -0.61098784  0.07670496  0.88105243];奖励reward = 1.0
# 当前状态state = [-0.06771625 -0.41698694  0.094326    0.6134359 ];奖励reward = 1.0
# 当前状态state = [-0.07605599 -0.2233009   0.10659473  0.35188913];奖励reward = 1.0
# 当前状态state = [-0.08052201 -0.0298435   0.11363251  0.09462961];奖励reward = 1.0
# 当前状态state = [-0.08111888  0.1634819   0.1155251  -0.1601522 ];奖励reward = 1.0
# 当前状态state = [-0.07784924  0.3567767   0.11232205 -0.4142729 ];奖励reward = 1.0
# 当前状态state = [-0.07071371  0.55014235  0.1040366  -0.6695403 ];奖励reward = 1.0
# 当前状态state = [-0.05971086  0.3537395   0.09064579 -0.34599733];奖励reward = 1.0
# 当前状态state = [-0.05263607  0.15745293  0.08372585 -0.02616286];奖励reward = 1.0
# 当前状态state = [-0.04948701  0.3512806   0.08320259 -0.29129925];奖励reward = 1.0
# 当前状态state = [-0.0424614   0.15507694  0.0773766   0.02642148];奖励reward = 1.0
# 当前状态state = [-0.03935986  0.3490089   0.07790503 -0.24088003];奖励reward = 1.0
# 当前状态state = [-0.03237968  0.1528655   0.07308743  0.07532358];奖励reward = 1.0
# 当前状态state = [-0.02932237 -0.04322399  0.0745939   0.39014116];奖励reward = 1.0
# 当前状态state = [-0.03018685  0.15076438  0.08239672  0.12187806];奖励reward = 1.0
# 当前状态state = [-0.02717157 -0.04543549  0.08483429  0.43937662];奖励reward = 1.0
# 当前状态state = [-0.02808028  0.14838979  0.09362182  0.17459565];奖励reward = 1.0
# 当前状态state = [-0.02511248 -0.04793869  0.09711374  0.4952833 ];奖励reward = 1.0
# 当前状态state = [-0.02607125 -0.24428637  0.1070194   0.8169237 ];奖励reward = 1.0
# 当前状态state = [-0.03095698 -0.44069794  0.12335787  1.1412592 ];奖励reward = 1.0
# 当前状态state = [-0.03977094 -0.24738503  0.14618306  0.8896685 ];奖励reward = 1.0
# 当前状态state = [-0.04471864 -0.05451676  0.16397643  0.6462767 ];奖励reward = 1.0
# 当前状态state = [-0.04580897 -0.25149783  0.17690197  0.98577815];奖励reward = 1.0
# 当前状态state = [-0.05083893 -0.05912939  0.19661753  0.7534671 ];奖励reward = 1.0
# 当前状态state = [-0.05202152  0.13281709  0.21168686  0.5285286 ];奖励reward = 1.0
# done
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# ...
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\xiandan\miniconda3\envs\d2l\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。

# %%
import gym
import time

#生成环境
env = gym.make('MountainCarContinuous-v0',render_mode='human')

#环境初始化
state = env.reset()

#循环交互
while True:
    #渲染画面
#     env.render()
    
    #选择随机动作
    action = env.action_space.sample()
    
    print("选择动作",action)
    #环境交互
    state,reward,terminated,truncated,info = env.step(action)
    
    #打印
    print("当前状态state = {};奖励reward = {}".format(state,reward))
    
    # 判断当前episode 是否完成
    if terminated:
        print("done")
        break
    time.sleep(0.1)
    
#环境结束
# env.close()
# Out:
# 选择动作 [-0.22357771]
# 当前状态state = [-5.4058522e-01 -2.0959339e-04];奖励reward = -0.004998699151717379
# 选择动作 [-0.20737204]
# 当前状态state = [-5.4097855e-01 -3.9330826e-04];奖励reward = -0.004300316278982397
# 选择动作 [-0.8178085]
# 当前状态state = [-0.5424683  -0.00148973];奖励reward = -0.06688107571850566
# 选择动作 [0.0054052]
# 当前状态state = [-0.54380846 -0.00134018];奖励reward = -2.921620408422119e-06
# 选择动作 [0.06593782]
# 当前状态state = [-0.5448983  -0.00108979];奖励reward = -0.0004347795723479209
# 选择动作 [0.42255223]
# 当前状态state = [-5.4519463e-01 -2.9632554e-04];奖励reward = -0.017855038536573886
# 选择动作 [0.8521001]
# 当前状态state = [-0.54405093  0.00114368];奖励reward = -0.07260745366071185
# 选择动作 [0.52924997]
# 当前状态state = [-0.54196006  0.00209085];奖励reward = -0.02801055266640198
# 选择动作 [0.6455579]
# 当前状态state = [-0.5387632   0.00319683];奖励reward = -0.04167449769486212
# 选择动作 [0.05859747]
# 当前状态state = [-0.5353648   0.00339842];奖励reward = -0.000343366323722677
# 选择动作 [0.16291551]
# 当前状态state = [-0.5316338   0.00373102];奖励reward = -0.002654146434979965
# 选择动作 [-0.94579285]
# 当前状态state = [-0.52926123  0.00237259];奖励reward = -0.08945241223601422
# 选择动作 [0.6090763]
# 当前状态state = [-0.52593255  0.00332867];奖励reward = -0.03709739649552013
# 选择动作 [-0.4344171]
# 当前状态state = [-0.523238    0.00269454];奖励reward = -0.018871821569558113
# 选择动作 [-0.17120373]
# 当前状态state = [-0.520803    0.00243503];奖励reward = -0.002931071801869223
# 选择动作 [0.36560592]
# 当前状态state = [-0.5178405   0.00296247];奖励reward = -0.013366768914355821
# 选择动作 [-0.29790863]
# 当前状态state = [-0.5153681   0.00247242];奖励reward = -0.008874955418038954
# 选择动作 [-0.57265323]
# 当前状态state = [-0.51381636  0.00155172];奖励reward = -0.032793172641635594
# 选择动作 [-0.26244688]
# 当前状态state = [-0.5127317   0.00108469];奖励reward = -0.006887836500050071
# 选择动作 [0.46666467]
# 当前状态state = [-0.51102847  0.0017032 ];奖励reward = -0.021777591599756365
# 选择动作 [0.8656774]
# 当前状态state = [-0.508121    0.00290746];奖励reward = -0.07493973891344617
# 选择动作 [0.76373357]
# 当前状态state = [-0.504184    0.00393702];奖励reward = -0.05832889595407984
# 选择动作 [-0.28047308]
# 当前状态state = [-0.50081325  0.00337078];奖励reward = -0.007866515043206679
# 选择动作 [0.553466]
# 当前状态state = [-0.49678302  0.00403022];奖励reward = -0.030632463752468555
# 选择动作 [-0.62199503]
# 当前状态state = [-0.49388668  0.00289633];奖励reward = -0.038687781962574164
# 选择动作 [0.16662215]
# 当前状态state = [-0.49096295  0.00292372];奖励reward = -0.0027762939858917202
# 选择动作 [-0.06376343]
# 当前状态state = [-0.48837927  0.00258369];奖励reward = -0.0004065775286526352
# 选择动作 [0.915022]
# 当前状态state = [-0.4846867   0.00369257];奖励reward = -0.0837265288980703
# 选择动作 [-0.38000128]
# 当前状态state = [-0.4818553   0.00283139];奖励reward = -0.014440097031756327
# 选择动作 [0.67012745]
# 当前状态state = [-0.47833097  0.00352433];奖励reward = -0.044907080114643706
# 选择动作 [-0.1802933]
# 当前状态state = [-0.47541556  0.00291542];奖励reward = -0.0032505676443826074
# 选择动作 [0.46476975]
# 当前状态state = [-0.4721631   0.00325246];奖励reward = -0.021601092128984423
# 选择动作 [0.39478573]
# 当前状态state = [-0.4687027  0.0034604];奖励reward = -0.015585577421514875
# 选择动作 [0.57474446]
# 当前状态state = [-0.46479005  0.00391265];奖励reward = -0.03303311977111321
# 选择动作 [0.36087066]
# 当前状态state = [-0.46077487  0.00401518];奖励reward = -0.013022763278067728
# 选择动作 [-0.267365]
# 当前状态state = [-0.45762914  0.00314573];奖励reward = -0.007148404781972407
# 选择动作 [-0.50975287]
# 当前状态state = [-0.4557396   0.00188956];奖励reward = -0.025984798807157008
# 选择动作 [0.7968903]
# 当前状态state = [-0.45316014  0.00257946];奖励reward = -0.06350341795496242
# 选择动作 [0.2434384]
# 当前状态state = [-0.4507399   0.00242025];奖励reward = -0.005926225112681838
# 选择动作 [-0.89111304]
# 当前状态state = [-0.4501984   0.00054148];奖励reward = -0.07940824551042738
# 选择动作 [-0.04503967]
# 当前状态state = [-4.5027056e-01 -7.2147341e-05];奖励reward = -0.00020285720903071708
# 选择动作 [-0.26526344]
# 当前状态state = [-0.45128614 -0.00101558];奖励reward = -0.00703646916588383
# 选择动作 [-0.7258738]
# 当前状态state = [-0.45392862 -0.00264249];奖励reward = -0.052689281407994316
# 选择动作 [0.9366081]
# 当前状态state = [-0.45568493 -0.00175631];奖励reward = -0.08772346882074658
# 选择动作 [-0.98217636]
# 当前状态state = [-0.45942035 -0.00373541];奖励reward = -0.09646704089555591
# 选择动作 [0.6850402]
# 当前状态state = [-0.46260658 -0.00318622];奖励reward = -0.04692800426173314
# 选择动作 [0.01863931]
# 当前状态state = [-0.46621972 -0.00361315];奖励reward = -3.4742371349192126e-05
# 选择动作 [-0.25585592]
# 当前状态state = [-0.4706449  -0.00442516];奖励reward = -0.006546225074011147
# 选择动作 [0.9030905]
# 当前状态state = [-0.4741109  -0.00346601];奖励reward = -0.08155724096295672
# 选择动作 [0.5896726]
# 当前状态state = [-0.4770622 -0.0029513];奖励reward = -0.0347713804750871
# 选择动作 [-0.63349944]
# 当前状态state = [-0.48131162 -0.00424944];奖励reward = -0.040132154495413276
# 选择动作 [-0.56604636]
# 当前状态state = [-0.48672643 -0.00541481];奖励reward = -0.03204084784482717
# 选择动作 [0.84551424]
# 当前状态state = [-0.49114895 -0.00442252];奖励reward = -0.07148943264589924
# 选择动作 [-0.7957224]
# 当前状态state = [-0.49700803 -0.00585909];奖励reward = -0.0633174177622383
# 选择动作 [0.08172753]
# 当前状态state = [-0.50294375 -0.00593572];奖励reward = -0.0006679389900768663
# 选择动作 [0.62183905]
# 当前状态state = [-0.5081015  -0.00515777];奖励reward = -0.03866837997250059
# 选择动作 [-0.6674151]
# 当前状态state = [-0.5143766  -0.00627508];奖励reward = -0.04454428922879892
# 选择动作 [0.06259213]
# 当前状态state = [-0.52062696 -0.00625035];奖励reward = -0.0003917774290914056
# 选择动作 [0.0560054]
# 当前状态state = [-0.5268156  -0.00618863];奖励reward = -0.0003136604375391594
# 选择动作 [0.00273175]
# 当前状态state = [-0.53297603 -0.00616041];奖励reward = -7.462460720048285e-07
# 选择动作 [0.02504256]
# 当前状态state = [-0.5390286  -0.00605253];奖励reward = -6.271298089266659e-05
# 选择动作 [0.2063143]
# 当前状态state = [-0.544656   -0.00562737];奖励reward = -0.00425655885401719
# 选择动作 [-0.09545425]
# 当前状态state = [-0.5502687  -0.00561273];奖励reward = -0.000911151446472186
# 选择动作 [0.6946057]
# 当前状态state = [-0.5546397  -0.00437101];奖励reward = -0.04824770897560171
# 选择动作 [0.43558392]
# 当前状态state = [-0.55812484 -0.00348516];奖励reward = -0.01897333507411867
# 选择动作 [0.7176171]
# 当前状态state = [-0.5602751  -0.00215026];奖励reward = -0.05149742943426681
# 选择动作 [-0.58060634]
# 当前状态state = [-0.5630217  -0.00274665];奖励reward = -0.03371037236297667
# 选择动作 [0.60787064]
# 当前状态state = [-0.5645616  -0.00153986];奖励reward = -0.03695067129929761
# 选择动作 [0.39248562]
# 当前状态state = [-0.5652063  -0.00064468];奖励reward = -0.015404496080100217
# 选择动作 [0.8934777]
# 当前状态state = [-0.5641995   0.00100678];奖励reward = -0.07983023616184824
# 选择动作 [0.89830256]
# 当前状态state = [-0.5615415   0.00265799];奖励reward = -0.08069474804708535
# 选择动作 [0.30000216]
# 当前状态state = [-0.5581496   0.00339195];奖励reward = -0.009000129461754014
# 选择动作 [-0.17388564]
# 当前状态state = [-0.5547598   0.00338979];奖励reward = -0.0030236217009221634
# 选择动作 [0.64303434]
# 当前状态state = [-0.5501721   0.00458771];奖励reward = -0.041349316107029216
# 选择动作 [0.26057008]
# 当前状态state = [-0.5449944   0.00517765];奖励reward = -0.006789676611603657
# 选择动作 [0.7362733]
# 当前状态state = [-0.538552    0.00644242];奖励reward = -0.05420983556925876
# 选择动作 [0.49727744]
# 当前状态state = [-0.53125155  0.00730044];奖励reward = -0.024728485098095023
# 选择动作 [-0.2929674]
# 当前状态state = [-0.5243332   0.00691838];奖励reward = -0.008582990267493873
# 选择动作 [0.81338656]
# 当前状态state = [-0.5161892   0.00814397];奖励reward = -0.06615976951531054
# 选择动作 [-0.9750124]
# 当前状态state = [-0.5095633   0.00662589];奖励reward = -0.09506492222898402
# 选择动作 [0.59218633]
# 当前状态state = [-0.5021544   0.00740893];奖励reward = -0.03506846515102922
# 选择动作 [0.37321615]
# 当前状态state = [-0.49434638  0.00780803];奖励reward = -0.01392902962563767
# 选择动作 [-0.5686197]
# 当前状态state = [-0.4876104   0.00673599];奖励reward = -0.032332839517130195
# 选择动作 [0.18873236]
# 当前状态state = [-0.4808607  0.0067497];奖励reward = -0.003561990213829436
# 选择动作 [-0.7868486]
# 当前状态state = [-0.47561094  0.00524977];奖励reward = -0.06191307266854587
# 选择动作 [-0.688518]
# 当前状态state = [-0.4717526   0.00385833];奖励reward = -0.04740570194251781
# 选择动作 [0.8945629]
# 当前状态state = [-0.46693972  0.00481289];奖励reward = -0.08002427821751645
# 选择动作 [-0.7636625]
# 当前状态state = [-0.46369523  0.0032445 ];奖励reward = -0.058318043997886454
# 选择动作 [0.7301137]
# 当前状态state = [-0.45980242  0.00389281];奖励reward = -0.05330659932156756
# 选择动作 [0.00402652]
# 当前状态state = [-0.45637912  0.00342329];奖励reward = -1.6212901341516873e-06
# 选择动作 [-0.9490909]
# 当前状态state = [-0.4548802   0.00149892];奖励reward = -0.09007735327365972
# 选择动作 [-0.15615898]
# 当前状态state = [-0.45412728  0.00075293];奖励reward = -0.0024385628192536758
# 选择动作 [-0.23496544]
# 当前状态state = [-4.5424408e-01 -1.1678973e-04];奖励reward = -0.005520875969138217
# 选择动作 [-0.9389009]
# 当前状态state = [-0.45628563 -0.00204156];奖励reward = -0.08815348774236363
# 选择动作 [-0.451791]
# 当前状态state = [-0.4595063  -0.00322067];奖励reward = -0.020411509724036492
# 选择动作 [-0.31291106]
# 当前状态state = [-0.46367407 -0.00416777];奖励reward = -0.009791333361857913
# 选择动作 [-0.16420737]
# 当前状态state = [-0.46853516 -0.0048611 ];奖励reward = -0.0026964060063172646
# 选择动作 [0.00196856]
# 当前状态state = [-0.4738044  -0.00526925];奖励reward = -3.8752359718679405e-07
# 选择动作 [-0.52027625]
# 当前状态state = [-0.48022616 -0.00642173];奖励reward = -0.027068737470645844
# 选择动作 [-0.20413645]
# 当前状态state = [-0.48727846 -0.00705232];奖励reward = -0.004167168863383197
# 选择动作 [0.79685223]
# 当前状态state = [-0.49340737 -0.0061289 ];奖励reward = -0.0634973478090629
# 选择动作 [-0.3157454]
# 当前状态state = [-0.50023603 -0.00682865];奖励reward = -0.009969516602211926
# 选择动作 [0.31711236]
# 当前状态state = [-0.5067641  -0.00652805];奖励reward = -0.010056024659699236
# 选择动作 [-0.59422165]
# 当前状态state = [-0.5143097  -0.00754559];奖励reward = -0.035309937117569135
# 选择动作 [-0.79970497]
# 当前状态state = [-0.5231245  -0.00881481];奖励reward = -0.0639528037330198
# 选择动作 [-0.52825886]
# 当前状态state = [-0.5327353  -0.00961076];奖励reward = -0.027905742328602302
# 选择动作 [0.8073087]
# 当前状态state = [-0.5410666  -0.00833128];奖励reward = -0.06517472948874002
# 选择动作 [-0.22452451]
# 当前状态state = [-0.5496037  -0.00853712];奖励reward = -0.0050411256887145095
# 选择动作 [0.8530501]
# 当前状态state = [-0.5566664 -0.0070627];奖励reward = -0.07276944948189482
# 选择动作 [0.23468216]
# 当前状态state = [-0.5631294  -0.00646308];奖励reward = -0.005507571511254228
# 选择动作 [-0.40472487]
# 当前状态state = [-0.5699038  -0.00677438];奖励reward = -0.01638022172816003
# 选择动作 [0.05122844]
# 当前状态state = [-0.57625514 -0.00635137];奖励reward = -0.00026243528161418314
# 选择动作 [-0.8852331]
# 当前状态state = [-0.5835411  -0.00728593];奖励reward = -0.07836376488228645
# 选择动作 [0.27178058]
# 当前状态state = [-0.5899722  -0.00643111];奖励reward = -0.007386468381853551
# 选择动作 [-0.9575045]
# 当前状态state = [-0.59734505 -0.00737285];奖励reward = -0.09168148883546223
# 选择动作 [0.03681071]
# 当前状态state = [-0.6041141  -0.00676904];奖励reward = -0.00013550281719926365
# 选择动作 [0.90835446]
# 当前状态state = [-0.6089226 -0.0048085];奖励reward = -0.08251078271693793
# 选择动作 [0.91666496]
# 当前状态state = [-0.6117231  -0.00280054];奖励reward = -0.08402746452254775
# 选择动作 [-0.89553684]
# 当前状态state = [-0.6152137  -0.00349058];奖励reward = -0.08019862317291349
# 选择动作 [-0.43784967]
# 当前状态state = [-0.61868256 -0.00346886];奖励reward = -0.019171233408706547
# 选择动作 [0.34378493]
# 当前状态state = [-0.6209323  -0.00224969];奖励reward = -0.011818807694125156
# 选择动作 [-0.22449736]
# 当前状态state = [-0.62279904 -0.00186676];奖励reward = -0.005039906598107025
# 选择动作 [-0.567966]
# 当前状态state = [-0.6247847  -0.00198564];奖励reward = -0.03225853593723969
# 选择动作 [-0.4067174]
# 当前状态state = [-0.6266331  -0.00184843];奖励reward = -0.01654190351836258
# 选择动作 [-0.39607176]
# 当前状态state = [-0.62831515 -0.00168202];奖励reward = -0.01568728405322242
# 选择动作 [-0.11302868]
# 当前状态state = [-0.6293942  -0.00107905];奖励reward = -0.0012775483128347144
# 选择动作 [0.02200351]
# 当前状态state = [-6.2966001e-01 -2.6583264e-04];奖励reward = -4.841546588093028e-05
# 选择动作 [0.16682813]
# 当前状态state = [-0.6288935   0.00076651];奖励reward = -0.0027831623529665176
# 选择动作 [-0.43119124]
# 当前状态state = [-0.6279971   0.00089637];奖励reward = -0.0185925881814101
# 选择动作 [-0.34889233]
# 当前状态state = [-0.6268538   0.00114328];奖励reward = -0.012172585871668674
# 选择动作 [0.26210406]
# 当前状态state = [-0.6245553   0.00229852];奖励reward = -0.006869854048386604
# 选择动作 [0.926472]
# 当前状态state = [-0.6201214   0.00443388];奖励reward = -0.0858350382030583
# 选择动作 [0.9938069]
# 当前状态state = [-0.61348295  0.00663844];奖励reward = -0.09876521516928315
# 选择动作 [0.60747224]
# 当前状态state = [-0.6052673   0.00821564];奖励reward = -0.036902252349424104
# 选择动作 [0.02717505]
# 当前状态state = [-0.5964045   0.00886281];奖励reward = -7.384832537047117e-05
# 选择动作 [-0.0926217]
# 当前状态state = [-0.5871389   0.00926558];奖励reward = -0.0008578779121119818
# 选择动作 [0.68214476]
# 当前状态state = [-0.57637644  0.01076247];奖励reward = -0.046532147507640786
# 选择动作 [0.7972511]
# 当前状态state = [-0.5640239   0.01235253];奖励reward = -0.06356093249156772
# 选择动作 [0.3099285]
# 当前状态state = [-0.55090404  0.01311987];奖励reward = -0.00960556792112266
# 选择动作 [0.16908859]
# 当前状态state = [-0.537326    0.01357806];奖励reward = -0.002859095030941483
# 选择动作 [0.28098175]
# 当前状态state = [-0.5232235   0.01410246];奖励reward = -0.007895074343754605
# 选择动作 [0.6769085]
# 当前状态state = [-0.5081085   0.01511501];奖励reward = -0.04582051079523808
# 选择动作 [0.30368966]
# 当前状态state = [-0.4926541   0.01545441];奖励reward = -0.009222740876598223
# 选择动作 [0.04785373]
# 当前状态state = [-0.47735965  0.01529443];奖励reward = -0.00022899795341513874
# 选择动作 [-0.72341377]
# 当前状态state = [-0.46349603  0.01386363];奖励reward = -0.05233274760142628
# 选择动作 [0.5013387]
# 当前状态state = [-0.44932872  0.01416731];奖励reward = -0.02513405124937549
# 选择动作 [0.3698204]
# 当前状态state = [-0.43515912  0.01416961];奖励reward = -0.013676711802791975
# 选择动作 [-0.09313384]
# 当前状态state = [-0.42178476  0.01337437];奖励reward = -0.0008673912979282828
# 选择动作 [-0.26843467]
# 当前状态state = [-0.40956482  0.01221993];奖励reward = -0.00720571739626843
# 选择动作 [0.20108667]
# 当前状态state = [-0.39788193  0.01168289];奖励reward = -0.004043584891615471
# 选择动作 [0.67448926]
# 当前状态state = [-0.38610798  0.01177394];奖励reward = -0.045493576147742944
# 选择动作 [-0.347607]
# 当前状态state = [-0.37585765  0.01025034];奖励reward = -0.012083061724512678
# 选择动作 [-0.1675073]
# 当前状态state = [-0.3669307   0.00892695];奖励reward = -0.0028058697476712746
# 选择动作 [0.83691007]
# 当前状态state = [-0.35788062  0.00905009];奖励reward = -0.07004184635748381
# 选择动作 [-0.93557554]
# 当前状态state = [-0.3514262   0.00645441];奖励reward = -0.08753016000916923
# 选择动作 [-0.41644904]
# 当前状态state = [-0.3468311   0.00459509];奖励reward = -0.01734298030622492
# 选择动作 [-0.07175159]
# 当前状态state = [-0.34360814  0.00322298];奖励reward = -0.0005148290250346632
# 选择动作 [-0.03760789]
# 当前状态state = [-0.34172684  0.00188129];奖励reward = -0.00014143536420549996
# 选择动作 [0.9627867]
# 当前状态state = [-0.33969873  0.00202811];奖励reward = -0.09269581805938287
# 选择动作 [-0.27415985]
# 当前状态state = [-3.3939222e-01  3.0652748e-04];奖励reward = -0.007516362263374177
# 选择动作 [0.15242289]
# 当前状态state = [-0.34016934 -0.00077714];奖励reward = -0.0023232737416407413
# 选择动作 [-0.87146777]
# 当前状态state = [-0.34356102 -0.00339167];奖励reward = -0.0759456072660246
# 选择动作 [-0.3327808]
# 当前状态state = [-0.34873745 -0.00517642];奖励reward = -0.011074306631314902
# 选择动作 [0.00216622]
# 当前状态state = [-0.35516277 -0.00642531];奖励reward = -4.69252012795003e-07
# 选择动作 [0.6658283]
# 当前状态state = [-0.36179954 -0.00663676];奖励reward = -0.04433273085703071
# 选择动作 [-0.6026174]
# 当前状态state = [-0.3705066  -0.00870708];奖励reward = -0.03631477102976675
# 选择动作 [0.26797011]
# 当前状态state = [-0.37992    -0.00941338];奖励reward = -0.007180798250436826
# 选择动作 [-0.29675967]
# 当前状态state = [-0.39082307 -0.01090305];奖励reward = -0.00880662987782479
# 选择动作 [-0.84948844]
# 当前状态state = [-0.40397003 -0.01314697];奖励reward = -0.07216306048952995
# 选择动作 [0.21778114]
# 当前状态state = [-0.4176684  -0.01369838];奖励reward = -0.004742862554963367
# 选择动作 [-0.22151041]
# 当前状态state = [-0.43248022 -0.01481182];奖励reward = -0.004906686187518972
# 选择动作 [-0.9006974]
# 当前状态state = [-0.449318   -0.01683777];奖励reward = -0.0811255824572843
# 选择动作 [0.9446528]
# 当前状态state = [-0.4652913 -0.0159733];奖励reward = -0.08923689045969355
# 选择动作 [-0.19208297]
# 当前状态state = [-0.4819878  -0.01669651];奖励reward = -0.0036895867876673982
# 选择动作 [-0.84096617]
# 当前状态state = [-0.500257   -0.01826923];奖励reward = -0.07072240907854202
# 选择动作 [0.42991504]
# 当前状态state = [-0.5180563  -0.01779927];奖励reward = -0.018482694224710716
# 选择动作 [0.32159266]
# 当前状态state = [-0.5354147  -0.01735845];奖励reward = -0.010342183816714458
# 选择动作 [0.5124666]
# 当前状态state = [-0.5519158  -0.01650115];奖励reward = -0.026262202582987372
# 选择动作 [-0.46982083]
# 当前状态state = [-0.5689096  -0.01699376];奖励reward = -0.022073160971384544
# 选择动作 [0.7417838]
# 当前状态state = [-0.58445185 -0.0155423 ];奖励reward = -0.05502432025909663
# 选择动作 [0.32885104]
# 当前状态state = [-0.599047   -0.01459515];奖励reward = -0.010814300925696685
# 选择动作 [-0.26923022]
# 当前状态state = [-0.613485   -0.01443795];奖励reward = -0.0072484909606708395
# 选择动作 [-0.6416002]
# 当前状态state = [-0.6282193  -0.01473435];奖励reward = -0.041165080585239266
# 选择动作 [0.67146504]
# 当前状态state = [-0.6411746  -0.01295532];奖励reward = -0.04508652989393483
# 选择动作 [-0.89760566]
# 当前状态state = [-0.6546127  -0.01343808];奖励reward = -0.08056959165151625
# 选择动作 [-0.26585713]
# 当前状态state = [-0.6674921  -0.01287937];奖励reward = -0.007068001372554367
# 选择动作 [-0.54573584]
# 当前状态state = [-0.6801441  -0.01265198];奖励reward = -0.029782760272632915
# 选择动作 [0.86974835]
# 当前状态state = [-0.69036    -0.01021595];奖励reward = -0.07564621992128764
# 选择动作 [0.43267542]
# 当前状态state = [-0.6987278  -0.00836775];奖励reward = -0.018720802014343365
# 选择动作 [-0.02415532]
# 当前状态state = [-0.7058779  -0.00715011];奖励reward = -5.8347924331637885e-05
# 选择动作 [-0.18981309]
# 当前状态state = [-0.71201277 -0.00613486];奖励reward = -0.003602901002783399
# 选择动作 [0.6096465]
# 当前状态state = [-0.7158941  -0.00388134];奖励reward = -0.037166885393432735
# 选择动作 [0.21021073]
# 当前状态state = [-0.7180966  -0.00220248];奖励reward = -0.004418854918464477
# 选择动作 [0.3648216]
# 当前状态state = [-7.183745e-01 -2.778947e-04];奖励reward = -0.013309480919147987
# 选择动作 [0.34753805]
# 当前状态state = [-0.716752    0.00162251];奖励reward = -0.012078269897074634
# 选择动作 [0.08239667]
# 当前状态state = [-0.71363693  0.00311503];奖励reward = -0.0006789211420878739
# 选择动作 [0.69020265]
# 当前状态state = [-0.7081373   0.00549966];奖励reward = -0.04763797027715136
# 选择动作 [0.8118734]
# 当前状态state = [-0.70010537  0.00803188];奖励reward = -0.06591383792575733
# 选择动作 [-0.79982495]
# 当前状态state = [-0.6920104   0.00809494];奖励reward = -0.06397199555681823
# 选择动作 [0.21438573]
# 当前状态state = [-0.68238384  0.00962655];奖励reward = -0.004596124251754242
# 选择动作 [0.7982429]
# 当前状态state = [-0.67041355  0.01197028];奖励reward = -0.06371917698630938
# 选择动作 [-0.7337795]
# 当前状态state = [-0.6584781   0.01193546];奖励reward = -0.05384323399359268
# 选择动作 [-0.10211747]
# 当前状态state = [-0.6457116  0.0127665];奖励reward = -0.00104279779645014
# 选择动作 [0.9042417]
# 当前状态state = [-0.63069326  0.01501836];奖励reward = -0.08176530178366335
# 选择动作 [0.11351489]
# 当前状态state = [-0.61471516  0.01597809];奖励reward = -0.0012885630877619348
# 选择动作 [0.8884162]
# 当前状态state = [-0.5967295   0.01798561];奖励reward = -0.07892832930256333
# 选择动作 [-0.7882987]
# 当前状态state = [-0.57938224  0.01734726];奖励reward = -0.06214148815422647
# 选择动作 [0.53255886]
# 当前状态state = [-0.56081975  0.01856252];奖励reward = -0.02836189376545839
# 选择动作 [-0.20149706]
# 当前状态state = [-0.5422809   0.01853885];奖励reward = -0.004060106641404127
# 选择动作 [0.61185783]
# 当前状态state = [-0.5226842   0.01959668];奖励reward = -0.03743700059411061
# 选择动作 [-0.7847036]
# 当前状态state = [-0.50427145  0.01841277];奖励reward = -0.06157597591999462
# 选择动作 [0.29862982]
# 当前状态state = [-0.48555562  0.01871584];奖励reward = -0.008917976960038132
# 选择动作 [-0.88685]
# 当前状态state = [-0.46845475  0.01710086];奖励reward = -0.07865029214850808
# 选择动作 [-0.9427467]
# 当前状态state = [-0.45317972  0.01527504];奖励reward = -0.08887713382045526
# 选择动作 [0.70529115]
# 当前状态state = [-0.43737096  0.01580876];奖励reward = -0.04974356090900898
# 选择动作 [-0.35633188]
# 当前状态state = [-0.42273623  0.01463474];奖励reward = -0.012697241216858758
# 选择动作 [-0.40269285]
# 当前状态state = [-0.4094505   0.01328572];奖励reward = -0.016216153498840313
# 选择动作 [-0.62411785]
# 当前状态state = [-0.39794043  0.01151007];奖励reward = -0.03895230922580595
# 选择动作 [-0.18457171]
# 当前状态state = [-0.38762748  0.01031293];奖励reward = -0.0034066717316961538
# 选择动作 [0.01905629]
# 当前状态state = [-0.3782777   0.00934978];奖励reward = -3.631420613754571e-05
# 选择动作 [-0.7432617]
# 当前状态state = [-0.37109852  0.00717918];奖励reward = -0.05524379471177241
# 选择动作 [-0.6256596]
# 当前状态state = [-0.3659621   0.00513642];奖励reward = -0.039144991630122666
# 选择动作 [-0.42505848]
# 当前状态state = [-0.36260197  0.00336014];奖励reward = -0.01806747148862229
# 选择动作 [0.64038795]
# 当前状态state = [-0.35944232  0.00315964];奖励reward = -0.04100967294865008
# 选择动作 [-0.6463739]
# 当前状态state = [-0.35843426  0.00100808];奖励reward = -0.04177992542722997
# 选择动作 [-0.4069753]
# 当前状态state = [-0.3592253  -0.00079105];奖励reward = -0.016562889409377224
# 选择动作 [0.10965768]
# 当前状态state = [-0.36103532 -0.00181001];奖励reward = -0.0012024805692512964
# 选择动作 [-0.9758156]
# 当前状态state = [-0.3654805 -0.0044452];奖励reward = -0.09522160738767163
# 选择动作 [-0.7081301]
# 当前状态state = [-0.37212983 -0.00664931];奖励reward = -0.05014482685947428
# 选择动作 [-0.3847038]
# 当前状态state = [-0.38045353 -0.00832368];奖励reward = -0.014799700233262403
# 选择动作 [0.59548193]
# 当前状态state = [-0.3889249  -0.00847136];奖励reward = -0.03545987315328638
# 选择动作 [0.90702575]
# 当前状态state = [-0.39701852 -0.00809362];奖励reward = -0.08226957192387695
# 选择动作 [-0.95977074]
# 当前状态state = [-0.40747848 -0.01045997];奖励reward = -0.09211598715913319
# 选择动作 [-0.43564126]
# 当前状态state = [-0.4194453  -0.01196683];奖励reward = -0.018978330650389896
# 选择动作 [-0.87023866]
# 当前状态state = [-0.43348598 -0.01404069];奖励reward = -0.07573153284323696
# 选择动作 [-0.08871752]
# 当前状态state = [-0.4483274  -0.01484141];奖励reward = -0.0007870798396997004
# 选择动作 [-0.9081056]
# 当前状态state = [-0.46509072 -0.01676332];奖励reward = -0.08246558021847364
# 选择动作 [0.37551984]
# 当前状态state = [-0.48172733 -0.0166366 ];奖励reward = -0.01410151516676672
# 选择动作 [-0.8938769]
# 当前状态state = [-0.50001794 -0.01829062];奖励reward = -0.0799015930605961
# 选择动作 [0.7589716]
# 当前状态state = [-0.5173468  -0.01732887];奖励reward = -0.05760378469862104
# 选择动作 [0.63028437]
# 当前状态state = [-0.5337771  -0.01643033];奖励reward = -0.03972583857954568
# 选择动作 [-0.1588367]
# 当前状态state = [-0.5503694  -0.01659226];奖励reward = -0.0025229094907097682
# 选择动作 [0.94842976]
# 当前状态state = [-0.56533843 -0.01496905];奖励reward = -0.08995190159457458
# 选择动作 [0.4665691]
# 当前状态state = [-0.5792954  -0.01395697];奖励reward = -0.021768672120227796
# 选择动作 [-0.4783344]
# 当前状态state = [-0.5935541  -0.01425869];奖励reward = -0.022880379542755326
# 选择动作 [0.11165298]
# 当前状态state = [-0.60712445 -0.01357039];奖励reward = -0.001246638744370371
# 选择动作 [-0.44955602]
# 当前状态state = [-0.62074924 -0.01362481];奖励reward = -0.02021006177098963
# 选择动作 [0.8463951]
# 当前状态state = [-0.6323861  -0.01163686];奖励reward = -0.07163846235279757
# 选择动作 [0.26863912]
# 当前状态state = [-0.6428185  -0.01043241];奖励reward = -0.007216697544007023
# 选择动作 [0.32034108]
# 当前状态state = [-0.6518952  -0.00907669];奖励reward = -0.010261840780924647
# 选择动作 [0.75191796]
# 当前状态state = [-0.6589054  -0.00701017];奖励reward = -0.05653806159532593
# 选择动作 [0.05887488]
# 当前状态state = [-0.6648401 -0.0059347];奖励reward = -0.0003466250942424587
# 选择动作 [-0.73367214]
# 当前状态state = [-0.6708474  -0.00600731];奖励reward = -0.053827481198914034
# 选择动作 [-0.5890933]
# 当前状态state = [-0.6766696  -0.00582216];奖励reward = -0.03470309485312697
# 选择动作 [-0.7845793]
# 当前状态state = [-0.6825605  -0.00589092];奖励reward = -0.061556464195837185
# 选择动作 [-0.621031]
# 当前状态state = [-0.68823546 -0.00567493];奖励reward = -0.03856794859559934
# 选择动作 [0.21121776]
# 当前状态state = [-0.6924084  -0.00417292];奖励reward = -0.004461294257863813
# 选择动作 [-0.37288105]
# 当前状态state = [-0.695928  -0.0035196];奖励reward = -0.01390402810871052
# 选择动作 [-0.5664076]
# 当前状态state = [-0.6990615  -0.00313355];奖励reward = -0.03208175930213351
# 选择动作 [-0.7598193]
# 当前状态state = [-0.70207876 -0.00301725];奖励reward = -0.057732541239520076
# 选择动作 [0.20288727]
# 当前状态state = [-0.7035161  -0.00143737];奖励reward = -0.004116324305972885
# 选择动作 [0.9335826]
# 当前状态state = [-0.7022683   0.00124781];奖励reward = -0.08715764783633838
# 选择动作 [-0.6080849]
# 当前状态state = [-0.7006558   0.00161246];奖励reward = -0.0369767266366182
# 选择动作 [-0.7381976]
# 当前状态state = [-0.6988843   0.00177152];奖励reward = -0.05449357330881846
# 选择动作 [-0.7390604]
# 当前状态state = [-0.69696647  0.00191781];奖励reward = -0.054621027768098435
# 选择动作 [-0.9072551]
# 当前状态state = [-0.6951671   0.00179935];奖励reward = -0.08231118402911797
# 选择动作 [-0.5101682]
# 当前状态state = [-0.6929023  0.0022648];奖励reward = -0.02602715869557102
# 选择动作 [-0.97292197]
# 当前状态state = [-0.690881   0.0020213];奖励reward = -0.09465771548565415
# 选择动作 [0.07106471]
# 当前状态state = [-0.6875505   0.00333051];奖励reward = -0.0005050193095087252
# 选择动作 [-0.97981316]
# 当前状态state = [-0.68450904  0.00304144];奖励reward = -0.0960033825593488
# 选择动作 [-0.82957053]
# 当前状态state = [-0.68155146  0.00295759];奖励reward = -0.06881872673057501
# 选择动作 [-0.3811181]
# 当前状态state = [-0.67802477  0.00352671];奖励reward = -0.01452509977330161
# 选择动作 [0.15561219]
# 当前状态state = [-0.67314744  0.00487734];奖励reward = -0.002421515230640581
# 选择动作 [0.30773434]
# 当前状态state = [-0.66672415  0.00642331];奖励reward = -0.009470042427946003
# 选择动作 [-0.10165568]
# 当前状态state = [-0.65941256  0.00731158];奖励reward = -0.0010333876658388031
# 选择动作 [0.41613188]
# 当前状态state = [-0.6504861   0.00892643];奖励reward = -0.017316574476456827
# 选择动作 [0.81981283]
# 当前状态state = [-0.63940114  0.01108499];奖励reward = -0.06720930832220838
# 选择动作 [0.13722]
# 当前状态state = [-0.62725914  0.01214197];奖励reward = -0.0018829327099219918
# 选择动作 [-0.89943194]
# 当前状态state = [-0.6157013   0.01155781];奖励reward = -0.0808977821695919
# 选择动作 [-0.38805845]
# 当前状态state = [-0.6040436   0.01165773];奖励reward = -0.015058936356432275
# 选择动作 [-0.5764058]
# 当前状态state = [-0.592653    0.01139062];奖励reward = -0.0332243673054311
# 选择动作 [-0.31369656]
# 当前状态state = [-0.5812187   0.01143429];奖励reward = -0.00984055337910128
# 选择动作 [0.1509378]
# 当前状态state = [-0.56912804  0.01209069];奖励reward = -0.0022782218152372024
# 选择动作 [-0.6398996]
# 当前状态state = [-0.55765676  0.01147125];奖励reward = -0.04094715127634033
# 选择动作 [-0.5148617]
# 当前状态state = [-0.5467028   0.01095395];奖励reward = -0.026508257313265917
# 选择动作 [0.37943846]
# 当前状态state = [-0.5350065   0.01169625];奖励reward = -0.01439735448309456
# 选择动作 [0.53796965]
# 当前状态state = [-0.5224178   0.01258875];奖励reward = -0.028941134307092754
# 选择动作 [0.9165934]
# 当前状态state = [-0.508463    0.01395478];奖励reward = -0.08401434111008577
# 选择动作 [-0.1681544]
# 当前状态state = [-0.49487397  0.01358907];奖励reward = -0.0028275903439079157
# 选择动作 [-0.54592925]
# 当前状态state = [-0.48231897  0.012555  ];奖励reward = -0.029803874939179666
# 选择动作 [-0.76552325]
# 当前状态state = [-0.47122106  0.01109791];奖励reward = -0.05860258537488541
# 选择动作 [-0.43418336]
# 当前状态state = [-0.46116564  0.01005542];奖励reward = -0.018851518935940705
# 选择动作 [-0.6939511]
# 当前状态state = [-0.45261666  0.00854898];奖励reward = -0.04815680879825699
# 选择动作 [-0.62096775]
# 当前状态state = [-0.4455275   0.00708917];奖励reward = -0.03856009413002681
# 选择动作 [-0.7312888]
# 当前状态state = [-0.44011545  0.00541204];奖励reward = -0.05347832954075926
# 选择动作 [0.37100425]
# 当前状态state = [-0.4347665   0.00534895];奖励reward = -0.01376441562084887
# 选择动作 [-0.13032566]
# 当前状态state = [-0.43027142  0.00449508];奖励reward = -0.0016984777682982123
# 选择动作 [-0.05153339]
# 当前状态state = [-0.4265445   0.00372693];奖励reward = -0.000265569026804581
# 选择动作 [0.60971266]
# 当前状态state = [-0.42262065  0.00392384];奖励reward = -0.03717495281455321
# 选择动作 [0.63948053]
# 当前状态state = [-0.4184834   0.00413725];奖励reward = -0.04089353498038726
# 选择动作 [-0.08156218]
# 当前状态state = [-0.41524386  0.00323954];奖励reward = -0.0006652388610423055
# 选择动作 [0.4209722]
# 当前状态state = [-0.41217127  0.00307258];奖励reward = -0.017721759169767728
# 选择动作 [0.30276984]
# 当前状态state = [-0.40946478  0.0027065 ];奖励reward = -0.009166957587050106
# 选择动作 [0.23685503]
# 当前状态state = [-0.40724236  0.00222241];奖励reward = -0.005610030526463561
# 选择动作 [-0.79284257]
# 当前状态state = [-4.0706426e-01  1.7808611e-04];奖励reward = -0.06285993359948386
# 选择动作 [-0.70085824]
# 当前状态state = [-0.40879378 -0.00172951];奖励reward = -0.04912022660708004
# 选择动作 [-0.03606804]
# 当前状态state = [-0.4114215  -0.00262773];奖励reward = -0.00013009035727468282
# 选择动作 [-0.16867565]
# 当前状态state = [-0.41512778 -0.00370628];奖励reward = -0.002845147361622247
# 选择动作 [0.9879729]
# 当前状态state = [-0.41815135 -0.00302358];奖励reward = -0.09760904811145998
# 选择动作 [-0.21597832]
# 当前状态state = [-0.42227662 -0.00412527];奖励reward = -0.004664663661637647
# 选择动作 [-0.24072173]
# 当前状态state = [-0.42751125 -0.00523462];奖励reward = -0.005794695243906834
# 选择动作 [-0.3514984]
# 当前状态state = [-0.43398383 -0.00647259];奖励reward = -0.012355112183136986
# 选择动作 [0.3496265]
# 当前状态state = [-0.440596   -0.00661219];奖励reward = -0.012223869742854367
# 选择动作 [0.36198092]
# 当前状态state = [-0.44728133 -0.00668533];奖励reward = -0.013103018287461056
# 选择动作 [-0.6115258]
# 当前状态state = [-0.45545134 -0.00817001];奖励reward = -0.037396377226883715
# 选择动作 [0.09978105]
# 当前状态state = [-0.46397924 -0.00852789];奖励reward = -0.000995625819416568
# 选择动作 [0.02887003]
# 当前状态state = [-0.4729086  -0.00892936];奖励reward = -8.334788112093796e-05
# 选择动作 [-0.5362847]
# 当前状态state = [-0.48302108 -0.0101125 ];奖励reward = -0.028760126351022566
# 选择动作 [0.5019757]
# 当前状态state = [-0.4926842  -0.00966311];奖励reward = -0.02519796186107648
# 选择动作 [-0.37972927]
# 当前状态state = [-0.50314844 -0.01046423];奖励reward = -0.014419431920487114
# 选择动作 [-0.8745159]
# 当前状态state = [-0.5150777  -0.01192929];奖励reward = -0.07647780437429362
# 选择动作 [-0.4351059]
# 当前状态state = [-0.52772355 -0.01264585];奖励reward = -0.018931713554369713
# 选择动作 [0.51404387]
# 当前状态state = [-0.5395674  -0.01184385];奖励reward = -0.02642410978048737
# 选择动作 [-0.04190115]
# 当前状态state = [-0.5513544  -0.01178698];奖励reward = -0.00017557059632384992
# 选择动作 [-0.1957922]
# 当前状态state = [-0.5632272  -0.01187274];奖励reward = -0.0038334584868607636
# 选择动作 [0.53887963]
# 当前状态state = [-0.5739951  -0.01076791];奖励reward = -0.029039125880814254
# 选择动作 [-0.877353]
# 当前状态state = [-0.58570254 -0.0117074 ];奖励reward = -0.07697483086512627
# 选择动作 [0.14722233]
# 当前状态state = [-0.596726   -0.01102348];奖励reward = -0.0021674413039003194
# 选择动作 [-0.17040388]
# 当前状态state = [-0.60746104 -0.01073502];奖励reward = -0.0029037483294152237
# 选择动作 [0.2858717]
# 当前状态state = [-0.6171449  -0.00968386];奖励reward = -0.00817226370674442
# 选择动作 [0.51131576]
# 当前状态state = [-0.62536937 -0.00822447];奖励reward = -0.026144380948887047
# 选择动作 [0.2318652]
# 当前状态state = [-0.63249457 -0.00712519];奖励reward = -0.005376146977467133
# 选择动作 [0.29575017]
# 当前状态state = [-0.63837385 -0.0058793 ];奖励reward = -0.008746816361465992
# 选择动作 [-0.5625614]
# 当前状态state = [-0.6442531  -0.00587924];奖励reward = -0.03164753206512074
# 选择动作 [-0.8920258]
# 当前状态state = [-0.65058506 -0.006332  ];奖励reward = -0.07957100784640403
# 选择动作 [-0.17085132]
# 当前状态state = [-0.6562438  -0.00565875];奖励reward = -0.0029190173555414312
# 选择动作 [0.9773538]
# 当前状态state = [-0.65946776 -0.00322393];奖励reward = -0.0955220472392341
# 选择动作 [-0.38609982]
# 当前状态state = [-0.6622798  -0.00281205];奖励reward = -0.014907306742770743
# 选择动作 [-0.63934743]
# 当前状态state = [-0.6650405  -0.00276071];奖励reward = -0.040876514141849896
# 选择动作 [0.43200713]
# 当前状态state = [-0.6661239  -0.00108343];奖励reward = -0.018663016379295884
# 选择动作 [-0.742733]
# 当前状态state = [-0.6672848  -0.00116087];奖励reward = -0.05516523118276382
# 选择动作 [-0.7334149]
# 当前状态state = [-0.6685012  -0.00121641];奖励reward = -0.05378973985003199
# 选择动作 [0.36730945]
# 当前状态state = [-6.6811377e-01  3.8741861e-04];奖励reward = -0.013491623286974175
# 选择动作 [-0.95280206]
# 当前状态state = [-6.681053e-01  8.441613e-06];奖励reward = -0.0907831769417399
# 选择动作 [0.14746742]
# 当前状态state = [-0.6668255   0.00127981];奖励reward = -0.0021746639815498846
# 选择动作 [-0.3689452]
# 当前状态state = [-0.66505766  0.00176784];奖励reward = -0.013612056884682833
# 选择动作 [0.08022885]
# 当前状态state = [-0.6621401   0.00291757];奖励reward = -0.0006436668411710978
# 选择动作 [-0.6587565]
# 当前状态state = [-0.65920126  0.00293884];奖励reward = -0.04339601190750386
# 选择动作 [-0.4261548]
# 当前状态state = [-0.65591246  0.0032888 ];奖励reward = -0.018160790700776277
# 选择动作 [-0.5520491]
# 当前状态state = [-0.65248525  0.00342723];奖励reward = -0.030475820925136433
# 选择动作 [0.7124202]
# 当前状态state = [-0.6470466  0.0054386];奖励reward = -0.05075425771934192
# 选择动作 [0.50869596]
# 当前状态state = [-0.63994014  0.00710648];奖励reward = -0.025877157976596267
# 选择动作 [0.6236962]
# 当前状态state = [-0.63104314  0.00889698];奖励reward = -0.03889969598738077
# 选择动作 [-0.39515132]
# 当前状态state = [-0.62194693  0.0090962 ];奖励reward = -0.015614456342135341
# 选择动作 [-0.03441684]
# 当前状态state = [-0.6121754   0.00977153];奖励reward = -0.0001184518839819626
# 选择动作 [0.60516113]
# 当前状态state = [-0.6008396   0.01133581];奖励reward = -0.03662199937812751
# 选择动作 [0.34683785]
# 当前状态state = [-0.5884094  0.0124302];奖励reward = -0.012029649310002189
# 选择动作 [-0.2999566]
# 当前状态state = [-0.57594615  0.01246329];奖励reward = -0.00899739558467596
# 选择动作 [-0.01891384]
# 当前状态state = [-0.56312025  0.01282591];奖励reward = -3.577331652673266e-05
# 选择动作 [-0.8815415]
# 当前状态state = [-0.5513209   0.01179932];奖励reward = -0.07771153995695955
# 选择动作 [-0.44036222]
# 当前状态state = [-0.53997445  0.01134645];奖励reward = -0.01939188804367973
# 选择动作 [0.3873466]
# 当前状态state = [-0.52792424  0.01205024];奖励reward = -0.015003738506538244
# 选择动作 [0.09002691]
# 当前状态state = [-0.51570654  0.01221772];奖励reward = -0.0008104844096126718
# 选择动作 [-0.30871585]
# 当前状态state = [-0.5040111   0.01169546];奖励reward = -0.009530547611211748
# 选择动作 [0.15168028]
# 当前状态state = [-0.49223495  0.01177616];奖励reward = -0.002300690606611
# 选择动作 [-0.03152206]
# 当前状态state = [-0.48074096  0.01149399];奖励reward = -9.936401374344706e-05
# 选择动作 [0.47302195]
# 当前状态state = [-0.468858    0.01188298];奖励reward = -0.02237497692479176
# 选择动作 [-0.5318422]
# 当前状态state = [-0.4581815  0.0106765];奖励reward = -0.028285609607280906
# 选择动作 [0.5818381]
# 当前状态state = [-0.44711974  0.01106177];奖励reward = -0.03385355412679623
# 选择动作 [-0.50355035]
# 当前状态state = [-0.43738186  0.00973787];奖励reward = -0.025356295565589805
# 选择动作 [0.38122663]
# 当前状态state = [-0.4277116   0.00967027];奖励reward = -0.014533374267302524
# 选择动作 [-0.18766907]
# 当前状态state = [-0.41903213  0.00867949];奖励reward = -0.0035219679299772545
# 选择动作 [-0.22313997]
# 当前状态state = [-0.4114588   0.00757333];奖励reward = -0.004979144687864423
# 选择动作 [-0.4917756]
# 当前状态state = [-0.4054484   0.00601039];奖励reward = -0.02418432428230597
# 选择动作 [0.44440052]
# 当前状态state = [-0.3996391  0.0058093];奖励reward = -0.019749182140533696
# 选择动作 [-0.34219187]
# 当前状态state = [-0.3952515  0.0043876];奖励reward = -0.011709527930296205
# 选择动作 [-0.8680643]
# 当前状态state = [-0.393105    0.00214651];奖励reward = -0.07535356017200599
# 选择动作 [0.84668034]
# 当前状态state = [-0.39064237  0.00246263];奖励reward = -0.07168676034784519
# 选择动作 [0.8000257]
# 当前状态state = [-0.38795066  0.00269173];奖励reward = -0.06400411230970918
# 选择动作 [-0.8840075]
# 当前状态state = [-3.8757446e-01  3.7620598e-04];奖励reward = -0.0781469283965297
# 选择动作 [0.16219895]
# 当前状态state = [-3.8794705e-01 -3.7259870e-04];奖励reward = -0.002630849804456248
# 选择动作 [0.9030778]
# 当前状态state = [-3.8795456e-01 -7.5195485e-06];奖励reward = -0.08155494788978537
# 选择动作 [-0.65234697]
# 当前状态state = [-0.3899301  -0.00197553];奖励reward = -0.04255565675079112
# 选择动作 [0.55291384]
# 当前状态state = [-0.3920521  -0.00212202];奖励reward = -0.030571371953422855
# 选择动作 [0.33628985]
# 当前状态state = [-0.39463088 -0.00257877];奖励reward = -0.011309086513497935
# 选择动作 [-0.2409525]
# 当前状态state = [-0.3985144  -0.00388351];奖励reward = -0.005805811046641929
# 选择动作 [0.43998444]
# 当前状态state = [-0.4026542 -0.0041398];奖励reward = -0.01935863081491931
# 选择动作 [-0.64334655]
# 当前状态state = [-0.40864635 -0.00599213];奖励reward = -0.04138947809270235
# 选择动作 [-0.92311406]
# 当前状态state = [-0.4168683  -0.00822196];奖励reward = -0.08521395702724135
# 选择动作 [-0.97391075]
# 当前状态state = [-0.427338  -0.0104697];奖励reward = -0.09485021469370772
# 选择动作 [-0.5383473]
# 当前状态state = [-0.43932718 -0.01198918];奖励reward = -0.028981781958123422
# 选择动作 [0.59616077]
# 当前状态state = [-0.45104745 -0.01172027];奖励reward = -0.0355407663046222
# 选择动作 [0.0034329]
# 当前状态state = [-0.4633024  -0.01225496];奖励reward = -1.1784832414451532e-06
# 选择动作 [0.39837414]
# 当前状态state = [-0.47540957 -0.01210716];奖励reward = -0.01587019556299687
# 选择动作 [0.28752202]
# 当前状态state = [-0.48744562 -0.01203604];奖励reward = -0.00826689108093639
# 选择动作 [-0.06116131]
# 当前状态state = [-0.499844  -0.0123984];奖励reward = -0.00037407053217026895
# 选择动作 [0.1956717]
# 当前状态state = [-0.5121269 -0.0122829];奖励reward = -0.003828741707359829
# 选择动作 [-0.3024611]
# 当前状态state = [-0.52494955 -0.01282262];奖励reward = -0.009148270957490823
# 选择动作 [-0.95007414]
# 当前状态state = [-0.53918713 -0.0142376 ];奖励reward = -0.09026408643848108
# 选择动作 [-0.24198589]
# 当前状态state = [-0.5536708  -0.01448371];奖励reward = -0.005855716964706748
# 选择动作 [0.9574914]
# 当前状态state = [-0.56649303 -0.01282223];奖励reward = -0.09167897769714273
# 选择动作 [-0.7979035]
# 当前状态state = [-0.5801913  -0.01369827];奖励reward = -0.0636649960436845
# 选择动作 [-0.12681966]
# 当前状态state = [-0.59365743 -0.01346609];奖励reward = -0.0016083224970204536
# 选择动作 [-0.5593043]
# 当前状态state = [-0.6074409  -0.01378347];奖励reward = -0.031282129660951695
# 选择动作 [-0.4692246]
# 当前状态state = [-0.621306  -0.0138651];奖励reward = -0.02201717271070658
# 选择动作 [0.55143636]
# 当前状态state = [-0.6336216  -0.01231559];奖励reward = -0.030408206425920882
# 选择动作 [-0.08409154]
# 当前状态state = [-0.645253   -0.01163146];奖励reward = -0.0007071386544689473
# 选择动作 [-0.15042695]
# 当前状态state = [-0.6562178  -0.01096481];奖励reward = -0.002262826849904176
# 选择动作 [0.449148]
# 当前状态state = [-0.6655403  -0.00932248];奖励reward = -0.0201733925263202
# 选择动作 [0.24819033]
# 当前状态state = [-0.6734578  -0.00791751];奖励reward = -0.006159843915042118
# 选择动作 [-0.836698]
# 当前状态state = [-0.6815439 -0.0080861];奖励reward = -0.07000635359459616
# 选择动作 [-0.5125719]
# 当前状态state = [-0.6892581 -0.0077142];奖励reward = -0.026272992322816793
# 选择动作 [-0.12099458]
# 当前状态state = [-0.69596183 -0.00670376];奖励reward = -0.0014639687257272328
# 选择动作 [0.06624241]
# 当前状态state = [-0.70133036 -0.00536852];奖励reward = -0.00043880571121610593
# 选择动作 [0.4721441]
# 当前状态state = [-0.70471996 -0.00338959];奖励reward = -0.022292004841671178
# 选择动作 [0.3187362]
# 当前状态state = [-0.7063389  -0.00161894];奖励reward = -0.010159276236278459
# 选择动作 [0.41241282]
# 当前状态state = [-7.0603627e-01  3.0260530e-04];奖励reward = -0.01700843359533657
# 选择动作 [-0.70805514]
# 当前状态state = [-7.0549476e-01  5.4150802e-04];奖励reward = -0.05013420792808035
# 选择动作 [-0.7320219]
# 当前状态state = [-0.70475376  0.00074099];奖励reward = -0.05358561028291575
# 选择动作 [-0.43051678]
# 当前状态state = [-0.7033658   0.00138798];奖励reward = -0.01853446973645454
# 选择动作 [-0.05126951]
# 当前状态state = [-0.7007709   0.00259491];奖励reward = -0.00026285629246562
# 选择动作 [0.8046022]
# 当前状态state = [-0.695702    0.00506892];奖励reward = -0.06473847095031182
# 选择动作 [-0.2845812]
# 当前状态state = [-0.6898258   0.00587623];奖励reward = -0.008098646746958682
# 选择动作 [-0.2047344]
# 当前状态state = [-0.68306094  0.0067648 ];奖励reward = -0.004191617450844932
# 选择动作 [-0.24583027]
# 当前状态state = [-0.67551404  0.00754692];奖励reward = -0.006043252050160763
# 选择动作 [-0.975579]
# 当前状态state = [-0.66833013  0.00718389];奖励reward = -0.09517544308224046
# 选择动作 [0.9988826]
# 当前状态state = [-0.6585962   0.00973391];奖励reward = -0.0997766432050046
# 选择动作 [-0.8544034]
# 当前状态state = [-0.6491589   0.00943733];奖励reward = -0.07300051299100829
# 选择动作 [-0.5903325]
# 当前状态state = [-0.6396875   0.00947142];奖励reward = -0.03484924701044747
# 选择动作 [-0.30644938]
# 当前状态state = [-0.62982255  0.00986492];奖励reward = -0.009391122464583734
# 选择动作 [-0.41569898]
# 当前状态state = [-0.61979795  0.01002463];奖励reward = -0.017280563808594798
# 选择动作 [0.3650347]
# 当前状态state = [-0.60851425  0.01128371];奖励reward = -0.013325033179525292
# 选择动作 [-0.23599055]
# 当前状态state = [-0.5969545   0.01155972];奖励reward = -0.005569154162174162
# 选择动作 [-0.9349578]
# 当前状态state = [-0.5862515   0.01070302];奖励reward = -0.08741460920735769
# 选择动作 [-0.23662564]
# 当前状态state = [-0.5754363   0.01081522];奖励reward = -0.005599169425522721
# 选择动作 [-0.21621323]
# 当前状态state = [-0.5645582   0.01087811];奖励reward = -0.0046748159234994095
# 选择动作 [0.45393375]
# 当前状态state = [-0.5526928   0.01186544];奖励reward = -0.0206055845414995
# 选择动作 [0.14318117]
# 当前状态state = [-0.54039466  0.01229814];奖励reward = -0.002050084887252357
# 选择动作 [-0.99223864]
# 当前状态state = [-0.52945894  0.01093569];奖励reward = -0.09845375202672955
# 选择动作 [0.77784413]
# 当前状态state = [-0.5173125   0.01214641];奖励reward = -0.060504149212008335
# 选择动作 [-0.62686515]
# 当前状态state = [-0.5061536   0.01115897];奖励reward = -0.03929599144594818
# 选择动作 [0.5365479]
# 当前状态state = [-0.49432057  0.01183301];奖励reward = -0.028788364818552736
# 选择动作 [0.55439943]
# 当前状态state = [-0.48187527  0.01244531];奖励reward = -0.03073587288179205
# 选择动作 [0.18478109]
# 当前状态state = [-0.4694649   0.01241037];奖励reward = -0.0034144051009121993
# 选择动作 [0.16661039]
# 当前状态state = [-0.45720884  0.01225606];奖励reward = -0.002775902203858838
# 选择动作 [0.7653523]
# 当前状态state = [-0.4442994   0.01290945];奖励reward = -0.058576415650918895
# 选择动作 [-0.6952797]
# 当前状态state = [-0.43302202  0.01127738];奖励reward = -0.04834138854909185
# 选择动作 [-0.030663]
# 当前状态state = [-0.42246163  0.01056039];奖励reward = -9.402193662835825e-05
# 选择动作 [0.37773123]
# 当前状态state = [-0.4120816   0.01038004];奖励reward = -0.01426808850146779
# 选择动作 [-0.87328506]
# 当前状态state = [-0.40383235  0.00824925];奖励reward = -0.07626267875667168
# 选择动作 [-0.10046624]
# 当前状态state = [-0.39661285  0.00721951];奖励reward = -0.0010093464670873908
# 选择动作 [0.7643869]
# 当前状态state = [-0.38917628  0.00743656];奖励reward = -0.058428732114867904
# 选择动作 [-0.5234602]
# 当前状态state = [-0.38350597  0.00567031];奖励reward = -0.027401059079332768
# 选择动作 [0.4525891]
# 当前状态state = [-0.3781768   0.00532915];奖励reward = -0.02048368885859908
# 选择动作 [-0.7664111]
# 当前状态state = [-0.37505367  0.00312314];奖励reward = -0.05873860135353404
# 选择动作 [0.43784738]
# 当前状态state = [-0.37235135  0.00270234];奖励reward = -0.0191710324556027
# 选择动作 [0.5411513]
# 当前状态state = [-0.36993313  0.00241823];奖励reward = -0.029284471344277564
# 选择动作 [-0.12398705]
# 当前状态state = [-0.36881298  0.00112015];奖励reward = -0.001537278828609434
# 选择动作 [0.67128915]
# 当前状态state = [-0.3678055   0.00100746];奖励reward = -0.0450629117465585
# 选择动作 [0.05479151]
# 当前状态state = [-3.6784223e-01 -3.6723122e-05];奖励reward = -0.000300210917137235
# 选择动作 [0.16466232]
# 当前状态state = [-0.36875808 -0.00091586];奖励reward = -0.0027113678455892524
# 选择动作 [0.34987342]
# 当前状态state = [-0.37026912 -0.00151103];奖励reward = -0.012241141252503952
# 选择动作 [-0.34944785]
# 当前状态state = [-0.37341416 -0.00314505];奖励reward = -0.012211379736244511
# 选择动作 [-0.36514857]
# 当前状态state = [-0.37819558 -0.00478143];奖励reward = -0.013333348117737476
# 选择动作 [-0.782976]
# 当前状态state = [-0.38520774 -0.00701217];奖励reward = -0.0613051372257619
# 选择动作 [0.1364531]
# 当前状态state = [-0.3930236  -0.00781586];奖励reward = -0.0018619450409788963
# 选择动作 [-0.2694207]
# 当前状态state = [-0.40219805 -0.00917445];奖励reward = -0.007258752069379515
# 选择动作 [-0.8099271]
# 当前状态state = [-0.4134779  -0.01127985];奖励reward = -0.06559819168774227
# 选择动作 [0.6099025]
# 当前状态state = [-0.42465386 -0.01117596];奖励reward = -0.037198106085567416
# 选择动作 [-0.8896025]
# 当前状态state = [-0.43789545 -0.0132416 ];奖励reward = -0.079139257654791
# 选择动作 [-0.03300599]
# 当前状态state = [-0.45182228 -0.01392683];奖励reward = -0.00010893953816882296
# 选择动作 [0.26149568]
# 当前状态state = [-0.46589103 -0.01406876];奖励reward = -0.006837999045831911
# 选择动作 [0.52598155]
# 当前状态state = [-0.47960147 -0.01371043];奖励reward = -0.02766565861521855
# 选择动作 [0.6417662]
# 当前状态state = [-0.49267828 -0.01307681];奖励reward = -0.04118638433059374
# 选择动作 [0.84659374]
# 当前状态state = [-0.50471675 -0.01203849];奖励reward = -0.07167209565473201
# 选择动作 [0.5031384]
# 当前状态state = [-0.5161421  -0.01142532];奖励reward = -0.025314827266471697
# 选择动作 [0.88566315]
# 当前状态state = [-0.5262948  -0.01015275];奖励reward = -0.0784399218351851
# 选择动作 [0.43188867]
# 当前状态state = [-0.53577954 -0.00948469];奖励reward = -0.018652782304048633
# 选择动作 [0.150003]
# 当前状态state = [-0.54494786 -0.00916835];奖励reward = -0.0022500900337165896
# 选择动作 [-0.87979734]
# 当前状态state = [-0.5552759  -0.01032804];奖励reward = -0.07740433584846329
# 选择动作 [0.46901178]
# 当前状态state = [-0.56466323 -0.0093873 ];奖励reward = -0.021997205315551584
# 选择动作 [-0.23084512]
# 当前状态state = [-0.5740896  -0.00942636];奖励reward = -0.005328947105731974
# 选择动作 [0.40356344]
# 当前状态state = [-0.58253336 -0.00844378];奖励reward = -0.01628634499803674
# 选择动作 [-0.45352238]
# 当前状态state = [-0.5912177  -0.00868436];奖励reward = -0.020568255294026373
# 选择动作 [-0.13215758]
# 当前状态state = [-0.5995966  -0.00837892];奖励reward = -0.0017465625704154997
# 选择动作 [-0.4767148]
# 当前状态state = [-0.60812557 -0.00852894];奖励reward = -0.022725699087832042
# 选择动作 [-0.1424104]
# 当前状态state = [-0.6162409  -0.00811537];奖励reward = -0.0020280721324539286
# 选择动作 [-0.8627439]
# 当前状态state = [-0.6249645  -0.00872358];奖励reward = -0.07443270613637801
# 选择动作 [-0.69315666]
# 当前状态state = [-0.6339792  -0.00901474];奖励reward = -0.04804661547521541
# 选择动作 [-0.35976496]
# 当前状态state = [-0.64272076 -0.00874158];奖励reward = -0.012943082888188774
# 选择动作 [0.5771078]
# 当前状态state = [-0.64972216 -0.0070014 ];奖励reward = -0.03330533979686976
# 选择动作 [-0.44036376]
# 当前状态state = [-0.6564606  -0.00673843];奖励reward = -0.019392024531613573
# 选择动作 [0.1105349]
# 当前状态state = [-0.66206294 -0.00560234];奖励reward = -0.0012217963882957207
# 选择动作 [-0.8948733]
# 当前状态state = [-0.66799873 -0.00593578];奖励reward = -0.08007982607384499
# 选择动作 [0.89004505]
# 当前状态state = [-0.67155    -0.00355126];奖励reward = -0.0792180185344492
# 选择动作 [-0.06286293]
# 当前状态state = [-0.674122 -0.002572];奖励reward = -0.000395174830538636
# 选择动作 [-0.6614216]
# 当前状态state = [-0.67659515 -0.00247319];奖励reward = -0.043747852898323815
# 选择动作 [-0.01544017]
# 当前状态state = [-0.6779839  -0.00138874];奖励reward = -2.383988122797243e-05
# 选择动作 [0.36969396]
# 当前状态state = [-6.7770118e-01  2.8273012e-04];奖励reward = -0.013667362755022429
# 选择动作 [0.90111554]
# 当前状态state = [-0.67495173  0.00274944];奖励reward = -0.08120092104636711
# 选择动作 [0.9776102]
# 当前状态state = [-0.66963935  0.0053124 ];奖励reward = -0.09557216461321937
# 选择动作 [-0.9137869]
# 当前状态state = [-0.664637    0.00500231];奖励reward = -0.08350064769047094
# 选择动作 [0.9546614]
# 当前状态state = [-0.6571762   0.00746081];奖励reward = -0.09113784438835673
# 选择动作 [-0.5934332]
# 当前状态state = [-0.6496303   0.00754589];奖励reward = -0.03521629644206179
# 选择动作 [-0.07621443]
# 当前状态state = [-0.6412759   0.00835445];奖励reward = -0.0005808639754278033
# 选择动作 [-0.7576413]
# 当前状态state = [-0.63319355  0.00808235];奖励reward = -0.057402036289227
# 选择动作 [-0.6456858]
# 当前状态state = [-0.6252725   0.00792105];奖励reward = -0.04169101419510213
# 选择动作 [0.29763916]
# 当前状态state = [-0.6161542   0.00911829];奖励reward = -0.00885890703681449
# 选择动作 [-0.27358833]
# 当前状态state = [-0.606761    0.00939319];奖励reward = -0.00748505740679315
# 选择动作 [-0.6679025]
# 当前状态state = [-0.5977524  0.0090086];奖励reward = -0.04460937885647276
# 选择动作 [0.695242]
# 当前状态state = [-0.5871493   0.01060304];奖励reward = -0.04833614214683202
# 选择动作 [0.65051085]
# 当前状态state = [-0.5750968   0.01205255];奖励reward = -0.042316436280430386
# 选择动作 [0.85574764]
# 当前状态state = [-0.5613759   0.01372088];奖励reward = -0.07323040235930343
# 选择动作 [-0.33820987]
# 当前状态state = [-0.54787964  0.01349628];奖励reward = -0.011438591445909196
# 选择动作 [-0.633745]
# 当前状态state = [-0.535152    0.01272761];奖励reward = -0.04016327436159237
# 选择动作 [0.46865198]
# 当前状态state = [-0.5216348   0.01351722];奖励reward = -0.02196346785094514
# 选择动作 [0.7417387]
# 当前状态state = [-0.5070197  0.0146151];奖励reward = -0.055017626499456185
# 选择动作 [0.19286887]
# 当前状态state = [-0.4922396   0.01478011];奖励reward = -0.003719840235628014
# 选择动作 [0.93384385]
# 当前状态state = [-0.47629356  0.01594603];奖励reward = -0.08720643382176263
# 选择动作 [-0.5687442]
# 当前状态state = [-0.46155426  0.01473932];奖励reward = -0.03234699452261793
# 选择动作 [0.2835538]
# 当前状态state = [-0.44685227  0.01470199];奖励reward = -0.00804027625573136
# 选择动作 [0.9761163]
# 当前状态state = [-0.43125662  0.01559564];奖励reward = -0.09528030304018245
# 选择动作 [-0.06493405]
# 当前状态state = [-0.41644213  0.0148145 ];奖励reward = -0.00042164311775728106
# 选择动作 [0.2568148]
# 当前状态state = [-0.40203232  0.01440982];奖励reward = -0.006595384543006677
# 选择动作 [-0.64523464]
# 当前状态state = [-0.38948202  0.01255029];奖励reward = -0.041632774635076336
# 选择动作 [-0.9046706]
# 当前状态state = [-0.3792677   0.01021433];奖励reward = -0.08184288874890769
# 选择动作 [-0.82187074]
# 当前状态state = [-0.37133515  0.00793255];奖励reward = -0.06754715202184834
# 选择动作 [0.05952937]
# 当前状态state = [-0.36441597  0.00691917];奖励reward = -0.0003543746078283283
# 选择动作 [-0.44196]
# 当前状态state = [-0.35930875  0.00510722];奖励reward = -0.01953286477452645
# 选择动作 [0.6368833]
# 当前状态state = [-0.3544291   0.00487966];奖励reward = -0.040562036128705264
# 选择动作 [0.9370796]
# 当前状态state = [-0.34935883  0.00507027];奖励reward = -0.08781181925548119
# 选择动作 [0.30580935]
# 当前状态state = [-0.34507793  0.00428089];奖励reward = -0.00935193578267155
# 选择动作 [0.58861697]
# 当前状态state = [-0.34118992  0.003888  ];奖励reward = -0.03464699340771773
# 选择动作 [0.23357333]
# 当前状态state = [-0.33825237  0.00293756];奖励reward = -0.005455650162195647
# 选择动作 [0.8862405]
# 当前状态state = [-0.335305    0.00294736];奖励reward = -0.07854221925210823
# 选择动作 [-0.1067908]
# 当前状态state = [-0.33385614  0.00144888];奖励reward = -0.0011404274093713919
# 选择动作 [-0.5716016]
# 当前状态state = [-0.3346121  -0.00075598];奖励reward = -0.032672842256948796
# 选择动作 [-0.5886234]
# 当前状态state = [-0.33759367 -0.00298159];奖励reward = -0.034647751232854775
# 选择动作 [0.932624]
# 当前状态state = [-0.3405001  -0.00290641];奖励reward = -0.08697874926026686
# 选择动作 [-0.9969242]
# 当前状态state = [-0.3462071  -0.00570701];奖励reward = -0.09938579034445959
# 选择动作 [0.14866681]
# ...
# 选择动作 [-0.18986009]
# 当前状态state = [-0.69222665 -0.0146905 ];奖励reward = -0.0036046854007715234
# 选择动作 [0.6622972]
# 当前状态state = [-0.7047123  -0.01248561];奖励reward = -0.043863756686949175
# 选择动作 [0.04249333]
# 当前状态state = [-0.71584165 -0.01112937];奖励reward = -0.00018056829629389262
# 选择动作 [-0.40046802]
# 当前状态state = [-0.7262085  -0.01036686];奖励reward = -0.016037463634924
# 选择动作 [-0.65912104]
# 当前状态state = [-0.7361363  -0.00992783];奖励reward = -0.04344405407957766
# 选择动作 [0.12502673]
# 当前状态state = [-0.7443884  -0.00825209];奖励reward = -0.0015631683885431792
# 选择动作 [0.5250986]
# 当前状态state = [-0.75031537 -0.00592697];奖励reward = -0.0275728562663776
# 选择动作 [-0.04876158]
# 当前状态state = [-0.7547432  -0.00442784];奖励reward = -0.00023776916976909896
# 选择动作 [0.79721177]
# 当前状态state = [-0.7563773  -0.00163407];奖励reward = -0.06355466002362534
# 选择动作 [-0.15810937]
# 当前状态state = [-7.5664115e-01 -2.6387689e-04];奖励reward = -0.002499857189954824
# 选择动作 [0.70755357]
# 当前状态state = [-0.75423485  0.00240633];奖励reward = -0.0500632048054829
# 选择动作 [0.34881216]
# 当前状态state = [-0.74971026  0.00452457];奖励reward = -0.012166992497032326
# 选择动作 [-0.8011444]
# 当前状态state = [-0.7448187   0.00489159];奖励reward = -0.0641832383460642
# 选择动作 [0.1378324]
# 当前状态state = [-0.73818034  0.00663835];奖励reward = -0.0018997771367196493
# 选择动作 [-0.48064607]
# 当前状态state = [-0.7307625   0.00741787];奖励reward = -0.02310206482768571
# 选择动作 [-0.76350206]
# 当前状态state = [-0.72303426  0.00772823];奖励reward = -0.05829353977117116
# 选择动作 [-0.335279]
# 当前状态state = [-0.7144008   0.00863343];奖励reward = -0.011241199971686912
# 选择动作 [-0.5190254]
# 当前状态state = [-0.7051918   0.00920903];奖励reward = -0.026938735066864086
# 选择动作 [-0.7384375]
# 当前状态state = [-0.6957948   0.00939695];奖励reward = -0.05452899026736624
# 选择动作 [0.01077741]
# 当前状态state = [-0.6851469  0.0106479];奖励reward = -1.161526491877396e-05
# 选择动作 [0.37281713]
# 当前状态state = [-0.6727751   0.01237186];奖励reward = -0.013899261159878851
# 选择动作 [-0.20351851]
# 当前状态state = [-0.65962666  0.01314843];奖励reward = -0.00414197838575916
# 选择动作 [-0.91966826]
# 当前状态state = [-0.6468656   0.01276106];奖励reward = -0.08457897033683857
# 选择动作 [0.8350645]
# 当前状态state = [-0.63194835  0.01491723];奖励reward = -0.0697332670338998
# 选择动作 [0.3400671]
# 当前状态state = [-0.61572266  0.01622572];奖励reward = -0.011564562475158269
# 选择动作 [0.25499383]
# 当前状态state = [-0.5984323   0.01729037];奖励reward = -0.006502185137507244
# 选择动作 [0.41481927]
# 当前状态state = [-0.57996315  0.01846915];奖励reward = -0.01720750270722826
# 选择动作 [-0.06980669]
# 当前状态state = [-0.56117797  0.01878516];奖励reward = -0.0004872973624449328
# 选择动作 [-0.7158163]
# 当前状态state = [-0.5431853   0.01799268];奖励reward = -0.051239300253067555
# 选择动作 [-0.3190458]
# 当前状态state = [-0.5255244   0.01766093];奖励reward = -0.010179023008554201
# 选择动作 [-0.85829115]
# 当前状态state = [-0.50913644  0.01638794];奖励reward = -0.07366636966910392
# 选择动作 [0.98454076]
# 当前状态state = [-0.49138013  0.01775631];奖励reward = -0.09693205091196298
# 选择动作 [-0.0852453]
# 当前状态state = [-0.47399294  0.01738718];奖励reward = -0.0007266760551344342
# 选择动作 [-0.8891016]
# 当前状态state = [-0.4583101   0.01568286];奖励reward = -0.07905016986686775
# 选择动作 [-0.48058486]
# 当前状态state = [-0.44383466  0.01447544];奖励reward = -0.02309618075151434
# 选择动作 [-0.5075105]
# 当前状态state = [-0.43071303  0.01312164];奖励reward = -0.02575668906237958
# 选择动作 [0.63776255]
# 当前状态state = [-0.4173224   0.01339062];奖励reward = -0.04067410657683013
# 选择动作 [-0.00672005]
# 当前状态state = [-0.4047255  0.0125969];奖励reward = -4.515903765102414e-06
# 选择动作 [-0.01251589]
# 当前状态state = [-0.39302012  0.01170535];奖励reward = -1.5664751280600967e-05
# 选择动作 [-0.76158357]
# 当前状态state = [-0.38341162  0.0096085 ];奖励reward = -0.05800095290151717
# 选择动作 [0.92120004]
# 当前状态state = [-0.373442    0.00996961];奖励reward = -0.08486095081735244
# 选择动作 [0.18094678]
# 当前状态state = [-0.36428943  0.00915256];奖励reward = -0.003274173799987268
# 选择动作 [-0.89102834]
# 当前状态state = [-0.35762328  0.00666617];奖励reward = -0.07939315109362077
# 选择动作 [-0.22276999]
# 当前状态state = [-0.35248527  0.005138  ];奖励reward = -0.004962646869561405
# 选择动作 [-0.2687714]
# 当前状态state = [-0.34897816  0.00350712];奖励reward = -0.007223807082715439
# 选择动作 [0.99492127]
# 当前状态state = [-0.34522924  0.00374893];奖励reward = -0.09898683275938006
# 选择动作 [-0.36601046]
# 当前状态state = [-0.34330416  0.00192508];奖励reward = -0.013396365483633677
# 选择动作 [-0.89657813]
# 当前状态state = [-0.3440112  -0.00070702];奖励reward = -0.08038523487642557
# 选择动作 [-0.32956535]
# 当前状态state = [-0.34649524 -0.00248406];奖励reward = -0.010861331744294845
# 选择动作 [-0.6359498]
# 当前状态state = [-0.3511999  -0.00470464];奖励reward = -0.040443213600869755
# 选择动作 [0.99073786]
# 当前状态state = [-0.35565454 -0.00445465];奖励reward = -0.09815614981907893
# 选择动作 [0.82552445]
# 当前状态state = [-0.36007786 -0.00442333];奖励reward = -0.06814906164720612
# 选择动作 [0.45668364]
# 当前状态state = [-0.36499396 -0.00491611];奖励reward = -0.020855994312682924
# 选择动作 [0.83210367]
# 当前状态state = [-0.36980706 -0.00481311];奖励reward = -0.06923965170340161
# 选择动作 [0.9743416]
# 当前状态state = [-0.3742716  -0.00446454];奖励reward = -0.09493414976238093
# 选择动作 [-0.7650903]
# 当前状态state = [-0.38096666 -0.00669505];奖励reward = -0.05853631468512255
# 选择动作 [0.64478517]
# 当前状态state = [-0.38773194 -0.00676526];奖励reward = -0.04157479100186379
# 选择动作 [-0.18023291]
# 当前状态state = [-0.39575857 -0.00802663];奖励reward = -0.003248390267686663
# 选择动作 [0.7512478]
# 当前状态state = [-0.4035938  -0.00783523];奖励reward = -0.056437329192039344
# 选择动作 [0.9300592]
# 当前状态state = [-0.41091466 -0.00732086];奖励reward = -0.08650101053945605
# 选择动作 [0.3467943]
# 当前状态state = [-0.41854444 -0.00762979];奖励reward = -0.01202662915284556
# 选择动作 [0.77240944]
# 当前状态state = [-0.42579055 -0.00724611];奖励reward = -0.05966163415905612
# 选择动作 [-0.54304874]
# 当前状态state = [-0.4345743  -0.00878376];奖励reward = -0.029490193340008377
# 选择动作 [-0.8055614]
# 当前状态state = [-0.4452262  -0.01065188];奖励reward = -0.06489292067118556
# 选择动作 [0.2646182]
# 当前状态state = [-0.45606354 -0.01083735];奖励reward = -0.007002278549596586
# 选择动作 [0.08767042]
# 当前状态state = [-0.46727243 -0.0112089 ];奖励reward = -0.0007686101778468847
# 选择动作 [0.14780667]
# 当前状态state = [-0.47868004 -0.01140763];奖励reward = -0.0021846812950486517
# 选择动作 [-0.10388608]
# 当前状态state = [-0.49057937 -0.01189933];奖励reward = -0.001079231664494801
# 选择动作 [0.9740106]
# 当前状态state = [-0.5012649  -0.01068555];奖励reward = -0.09486966230788454
# 选择动作 [-0.7002947]
# 当前状态state = [-0.5131683  -0.01190337];奖励reward = -0.04904126296524147
# 选择动作 [-0.11801742]
# 当前状态state = [-0.5253269  -0.01215862];奖励reward = -0.0013928111464217574
# 选择动作 [0.57606006]
# 当前状态state = [-0.53660846 -0.01128156];奖励reward = -0.033184518890953994
# 选择动作 [0.20348494]
# 当前状态state = [-0.54748726 -0.01087879];奖励reward = -0.004140611980917286
# 选择动作 [-0.71020925]
# 当前状态state = [-0.5592524  -0.01176509];奖励reward = -0.05043971794249416
# 选择动作 [0.00900823]
# 当前状态state = [-0.57073706 -0.01148469];奖励reward = -8.114813539451208e-06
# 选择动作 [-0.03231597]
# 当前状态state = [-0.5819179 -0.0111808];奖励reward = -0.00010443221233753658
# 选择动作 [-0.29085326]
# 当前状态state = [-0.5930998  -0.01118192];奖励reward = -0.008459561998557774
# 选择动作 [-0.00427322]
# 当前状态state = [-0.6037706  -0.01067084];奖励reward = -1.8260440710662387e-06
# 选择动作 [-0.36358708]
# 当前状态state = [-0.6143913  -0.01062071];奖励reward = -0.013219556578448888
# 选择动作 [-0.08067375]
# 当前状态state = [-0.6244605  -0.01006917];奖励reward = -0.0006508254619181031
# 选择动作 [-0.39297172]
# 当前状态state = [-0.63437414 -0.00991365];奖励reward = -0.01544267760771314
# 选择动作 [0.8415675]
# 当前状态state = [-0.6422098  -0.00783569];奖励reward = -0.07082358845366343
# 选择动作 [-0.04160243]
# 当前状态state = [-0.649237   -0.00702717];奖励reward = -0.00017307617889477658
# 选择动作 [-0.8967059]
# 当前状态state = [-0.65668905 -0.00745209];奖励reward = -0.08040815167633789
# 选择动作 [-0.40978423]
# 当前状态state = [-0.66378397 -0.0070949 ];奖励reward = -0.016792311319762467
# 选择动作 [-0.03202515]
# 当前状态state = [-0.66990626 -0.00612227];奖励reward = -0.00010256102936728185
# 选择动作 [-0.36261073]
# 当前状态state = [-0.67551005 -0.00560378];奖励reward = -0.013148653973332447
# 选择动作 [0.8452784]
# 当前状态state = [-0.6787456  -0.00323555];奖励reward = -0.07144955435859544
# 选择动作 [-0.64394295]
# 当前状态state = [-0.68182504 -0.00307943];奖励reward = -0.041466252563147066
# 选择动作 [0.31781027]
# 当前状态state = [-0.6832851  -0.00146008];奖励reward = -0.010100336594409587
# 选择动作 [-0.08034822]
# 当前状态state = [-6.837134e-01 -4.282420e-04];奖励reward = -0.0006455835813935773
# 选择动作 [0.09759273]
# 当前状态state = [-0.68284     0.00087336];奖励reward = -0.0009524340236392926
# 选择动作 [0.78700954]
# 当前状态state = [-0.6796367   0.00320327];奖励reward = -0.061938401167524054
# 选择动作 [0.9545596]
# 当前状态state = [-0.6738736   0.00576312];奖励reward = -0.09111840761434885
# 选择动作 [-0.90225184]
# 当前状态state = [-0.6683746   0.00549901];奖励reward = -0.08140583821297157
# 选择动作 [-0.63579226]
# 当前状态state = [-0.6627773   0.00559732];奖励reward = -0.04042317920286678
# 选择动作 [0.4355117]
# 当前状态state = [-0.6555129   0.00726436];奖励reward = -0.018967044803117974
# 选择动作 [-0.06421684]
# 当前状态state = [-0.6473812   0.00813177];奖励reward = -0.0004123802191138504
# 选择动作 [0.07118139]
# 当前状态state = [-0.63823545  0.00914572];奖励reward = -0.0005066789813846561
# 选择动作 [-0.6960953]
# 当前状态state = [-0.62929094  0.0089445 ];奖励reward = -0.048454864969713546
# 选择动作 [-0.3762037]
# 当前状态state = [-0.62013125  0.00915967];奖励reward = -0.014152921335917147
# 选择动作 [0.6469917]
# 当前状态state = [-0.6092872   0.01084408];奖励reward = -0.041859829834720585
# 选择动作 [0.3207316]
# 当前状态state = [-0.5973264   0.01196078];奖励reward = -0.010286876569151194
# 选择动作 [-0.2100506]
# 当前状态state = [-0.58513224  0.01219417];奖励reward = -0.0044121253630635465
# 选择动作 [0.6681878]
# 当前状态state = [-0.5714769   0.01365533];奖励reward = -0.04464749321526576
# 选择动作 [0.7060518]
# 当前状态state = [-0.5564046   0.01507226];奖励reward = -0.04985091816715795
# 选择动作 [-0.00260593]
# 当前状态state = [-0.5410906  0.015314 ];奖励reward = -6.790886787665931e-07
# 选择动作 [0.4554287]
# 当前状态state = [-0.5249623   0.01612827];奖励reward = -0.020741529141847882
# 选择动作 [0.1034759]
# 当前状态state = [-0.5086686   0.01629371];奖励reward = -0.0010707261571263338
# 选择动作 [-0.8640238]
# 当前状态state = [-0.49378285  0.01488574];奖励reward = -0.07465371350271113
# 选择动作 [0.8650504]
# 当前状态state = [-0.47782284  0.01595999];奖励reward = -0.07483121520862178
# 选择动作 [0.7866263]
# 当前状态state = [-0.46102515  0.01679769];奖励reward = -0.06187809033704675
# 选择动作 [0.10740693]
# 当前状态state = [-0.4445329   0.01649225];奖励reward = -0.0011536248426280205
# 选择动作 [-0.17886445]
# 当前状态state = [-0.4288964   0.01563651];奖励reward = -0.0031992491210020013
# 选择动作 [0.2633107]
# 当前状态state = [-0.41356567  0.01533072];奖励reward = -0.006933252507941834
# 选择动作 [0.7154907]
# 当前状态state = [-0.39797205  0.01559361];奖励reward = -0.051192694008990715
# 选择动作 [-0.49860352]
# 当前状态state = [-0.3840464   0.01392566];奖励reward = -0.02486054729261902
# 选择动作 [-0.17440447]
# 当前状态state = [-0.3713987   0.01264771];奖励reward = -0.0030416919892894082
# 选择动作 [-0.62465036]
# 当前状态state = [-0.3607902   0.01060849];奖励reward = -0.03901880711909059
# 选择动作 [0.16497236]
# 当前状态state = [-0.35110733  0.00968286];奖励reward = -0.0027215881181522406
# 选择动作 [0.6467648]
# 当前状态state = [-0.34169105  0.00941629];奖励reward = -0.041830472573269974
# 选择动作 [-0.99671453]
# 当前状态state = [-0.33506742  0.00662363];奖励reward = -0.09934398590481841
# 选择动作 [0.6573803]
# 当前状态state = [-0.32879752  0.0062699 ];奖励reward = -0.04321488363179107
# 选择动作 [-0.40856728]
# 当前状态state = [-0.32451972  0.0042778 ];奖励reward = -0.016692722194115907
# 选择动作 [-0.35493445]
# 当前状态state = [-0.32218024  0.00233949];奖励reward = -0.012597846661088853
# 选择动作 [0.56772685]
# 当前状态state = [-0.32040954  0.00177071];奖励reward = -0.032231377678959915
# 选择动作 [-0.84125066]
# 当前状态state = [-0.32133198 -0.00092245];奖励reward = -0.07077026696447888
# 选择动作 [0.63032377]
# 当前状态state = [-0.32273453 -0.00140257];奖励reward = -0.03973080520796799
# 选择动作 [-0.8944848]
# 当前状态state = [-0.32689577 -0.00416125];奖励reward = -0.08001030895997907
# 选择动作 [-0.02898312]
# 当前状态state = [-0.33249164 -0.00559585];奖励reward = -8.400212376997868e-05
# 选择动作 [-0.8038936]
# 当前状态state = [-0.3406494  -0.00815775];奖励reward = -0.06462449614993525
# 选择动作 [0.364215]
# 当前状态state = [-0.3495651  -0.00891569];奖励reward = -0.013265255643688878
# 选择动作 [0.511813]
# 当前状态state = [-0.35895982 -0.00939473];奖励reward = -0.026195253155666266
# 选择动作 [-0.98956436]
# 当前状态state = [-0.3710241  -0.01206427];奖励reward = -0.09792376209753151
# 选择动作 [-0.00283365]
# 当前状态state = [-0.38419738 -0.01317329];奖励reward = -8.02958145581812e-07
# 选择动作 [0.69161105]
# 当前状态state = [-0.39734855 -0.01315117];奖励reward = -0.04783258466391658
# 选择动作 [0.6502901]
# 当前状态state = [-0.4104487  -0.01310014];奖励reward = -0.042287717769528756
# 选择动作 [0.545815]
# 当前状态state = [-0.42356253 -0.01311384];奖励reward = -0.029791400439739848
# 选择动作 [-0.59259915]
# 当前状态state = [-0.43830433 -0.0147418 ];奖励reward = -0.03511737567510522
# 选择动作 [0.94986105]
# 当前状态state = [-0.4522541  -0.01394976];奖励reward = -0.09022360136461885
# 选择动作 [0.41916403]
# 当前状态state = [-0.46610612 -0.01385202];奖励reward = -0.01756984855078878
# 选择动作 [0.0599577]
# 当前状态state = [-0.48029727 -0.01419114];奖励reward = -0.0003594925994686707
# 选择动作 [-0.13009016]
# 当前状态state = [-0.4950074  -0.01471013];奖励reward = -0.001692345029029796
# 选择动作 [0.6312397]
# 当前状态state = [-0.50898486 -0.01397744];奖励reward = -0.039846357430670665
# 选择动作 [0.5848239]
# 当前状态state = [-0.5221946  -0.01320977];奖励reward = -0.034201900152229216
# 选择动作 [-0.8308793]
# 当前状态state = [-0.53666127 -0.01446662];奖励reward = -0.06903603630280522
# 选择动作 [-0.44372538]
# 当前状态state = [-0.5516955  -0.01503427];奖励reward = -0.019689221047887975
# 选择动作 [-0.27208108]
# 当前状态state = [-0.56692743 -0.01523191];奖励reward = -0.007402811251526842
# 选择动作 [0.48793456]
# 当前状态state = [-0.5811034  -0.01417596];奖励reward = -0.02380801344361041
# 选择动作 [0.9421594]
# 当前状态state = [-0.59343696 -0.01233357];奖励reward = -0.08876643619378798
# 选择动作 [-0.515819]
# 当前状态state = [-0.60602427 -0.01258734];奖励reward = -0.02660692542947949
# 选择动作 [0.16251498]
# 当前状态state = [-0.61775595 -0.01173166];奖励reward = -0.0026411120222039845
# 选择动作 [0.71743876]
# 当前状态state = [-0.62771463 -0.00995867];奖励reward = -0.05147183706477598
# 选择动作 [0.4128841]
# 当前状态state = [-0.6362857  -0.00857111];奖励reward = -0.01704732687779762
# 选择动作 [-0.1249248]
# 当前状态state = [-0.64421505 -0.00792935];奖励reward = -0.0015606205977354794
# 选择动作 [-0.8690974]
# 当前状态state = [-0.65256304 -0.00834799];奖励reward = -0.07553303109063769
# 选择动作 [-0.9477705]
# 当前状态state = [-0.6613894  -0.00882636];奖励reward = -0.08982688758241153
# 选择动作 [-0.8573732]
# 当前状态state = [-0.6704976  -0.00910817];奖励reward = -0.07350887663627681
# 选择动作 [-0.3140207]
# 当前状态state = [-0.6790104  -0.00851278];奖励reward = -0.009860899582196582
# 选择动作 [-0.24783075]
# 当前状态state = [-0.6867711  -0.00776071];奖励reward = -0.006142007993084064
# 选择动作 [-0.7182788]
# 当前状态state = [-0.69443375 -0.00766263];奖励reward = -0.05159244708499991
# 选择动作 [-0.78204876]
# 当前状态state = [-0.70204353 -0.0076098 ];奖励reward = -0.06116002659027267
# 选择动作 [-0.47864446]
# 当前状态state = [-0.70909595 -0.00705245];奖励reward = -0.022910051950959433
# 选择动作 [-0.7366345]
# 当前状态state = [-0.71593285 -0.00683687];奖励reward = -0.05426303760919496
# 选择动作 [-0.29920977]
# 当前状态state = [-0.72185475 -0.0059219 ];奖励reward = -0.008952648858215539
# 选择动作 [-0.41682017]
# 当前状态state = [-0.7270011  -0.00514634];奖励reward = -0.017373905286434878
# 选择动作 [0.9006532]
# 当前状态state = [-0.72936386 -0.00236277];奖励reward = -0.08111761568770569
# 选择动作 [-0.16353141]
# 当前状态state = [-0.73052484 -0.00116099];奖励reward = -0.0026742521308886547
# 选择动作 [0.18730308]
# 当前状态state = [-7.2995073e-01  5.7414034e-04];奖励reward = -0.0035082444210090325
# 选择动作 [0.30077064]
# 当前状态state = [-0.72747475  0.00247596];奖励reward = -0.009046297811052284
# 选择动作 [-0.26211601]
# 当前状态state = [-0.72395647  0.00351829];奖励reward = -0.006870480529716261
# 选择动作 [0.6907803]
# 当前状态state = [-0.7179882   0.00596828];奖励reward = -0.04771773980284166
# 选择动作 [0.01519139]
# 当前状态state = [-0.71062046  0.00736775];奖励reward = -2.3077827898124963e-05
# 选择动作 [0.81699014]
# 当前状态state = [-0.700697    0.00992345];奖励reward = -0.06674728841190358
# 选择动作 [0.05456832]
# 当前状态state = [-0.68942505  0.01127193];奖励reward = -0.0002977701603584571
# 选择动作 [-0.8444823]
# 当前状态state = [-0.6782268   0.01119824];奖励reward = -0.07131503595155807
# 选择动作 [-0.6552533]
# 当前状态state = [-0.6668929   0.01133392];奖励reward = -0.0429356875536783
# 选择动作 [-0.5579778]
# 当前状态state = [-0.655354    0.01153886];奖励reward = -0.031133922038362984
# 选择动作 [0.04690143]
# 当前状态state = [-0.64278215  0.01257185];奖励reward = -0.00021997442237193938
# 选择动作 [-0.07593787]
